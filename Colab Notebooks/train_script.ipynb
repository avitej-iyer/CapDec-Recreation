# %%
# !pip install torch transformers tqdm argparse typing
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.46.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.6)
# Collecting argparse
#   Downloading argparse-1.4.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting typing
#   Downloading typing-3.7.4.3.tar.gz (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 8.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.26.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)
# Downloading argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Building wheels for collected packages: typing
#   Building wheel for typing (setup.py) ... done
#   Created wheel for typing: filename=typing-3.7.4.3-py3-none-any.whl size=26303 sha256=9503bc3853fbe490ed52659413e0cde15f7904781440b2dd76d88bf95d820695
#   Stored in directory: /root/.cache/pip/wheels/7c/d0/9e/1f26ebb66d9e1732e4098bc5a6c2d91f6c9a529838f0284890
# Successfully built typing
# Installing collected packages: argparse, typing
# Successfully installed argparse-1.4.0 typing-3.7.4.3

# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- -------------------
# absl-py                            1.4.0
# accelerate                         1.1.1
# aiohappyeyeballs                   2.4.4
# aiohttp                            3.11.9
# aiosignal                          1.3.1
# alabaster                          1.0.0
# albucore                           0.0.19
# albumentations                     1.4.20
# altair                             4.2.2
# annotated-types                    0.7.0
# anyio                              3.7.1
# argon2-cffi                        23.1.0
# argon2-cffi-bindings               21.2.0
# array_record                       0.5.1
# arviz                              0.20.0
# astropy                            6.1.7
# astropy-iers-data                  0.2024.12.2.0.35.34
# astunparse                         1.6.3
# async-timeout                      4.0.3
# atpublic                           4.1.0
# attrs                              24.2.0
# audioread                          3.0.1
# autograd                           1.7.0
# babel                              2.16.0
# backcall                           0.2.0
# beautifulsoup4                     4.12.3
# bigframes                          1.27.0
# bigquery-magics                    0.4.0
# bleach                             6.2.0
# blinker                            1.9.0
# blis                               0.7.11
# blosc2                             2.7.1
# bokeh                              3.6.1
# Bottleneck                         1.4.2
# bqplot                             0.12.43
# branca                             0.8.0
# CacheControl                       0.14.1
# cachetools                         5.5.0
# catalogue                          2.0.10
# certifi                            2024.8.30
# cffi                               1.17.1
# chardet                            5.2.0
# charset-normalizer                 3.4.0
# chex                               0.1.87
# clarabel                           0.9.0
# click                              8.1.7
# cloudpathlib                       0.20.0
# cloudpickle                        3.1.0
# cmake                              3.30.5
# cmdstanpy                          1.2.4
# colorcet                           3.1.0
# colorlover                         0.3.0
# colour                             0.1.5
# community                          1.0.0b1
# confection                         0.1.5
# cons                               0.4.6
# contourpy                          1.3.1
# cryptography                       43.0.3
# cuda-python                        12.2.1
# cudf-cu12                          24.10.1
# cufflinks                          0.17.3
# cupy-cuda12x                       12.2.0
# cvxopt                             1.3.2
# cvxpy                              1.5.4
# cycler                             0.12.1
# cymem                              2.0.10
# Cython                             3.0.11
# dask                               2024.10.0
# datascience                        0.17.6
# db-dtypes                          1.3.1
# dbus-python                        1.2.18
# debugpy                            1.8.0
# decorator                          4.4.2
# defusedxml                         0.7.1
# Deprecated                         1.2.15
# diffusers                          0.31.0
# distro                             1.9.0
# dlib                               19.24.2
# dm-tree                            0.1.8
# docker-pycreds                     0.4.0
# docstring_parser                   0.16
# docutils                           0.21.2
# dopamine_rl                        4.0.9
# duckdb                             1.1.3
# earthengine-api                    1.2.0
# easydict                           1.13
# ecos                               2.0.14
# editdistance                       0.8.1
# eerepr                             0.0.4
# einops                             0.8.0
# en-core-web-sm                     3.7.1
# entrypoints                        0.4
# et_xmlfile                         2.0.0
# etils                              1.11.0
# etuples                            0.3.9
# eval_type_backport                 0.2.0
# exceptiongroup                     1.2.2
# fastai                             2.7.18
# fastcore                           1.7.22
# fastdownload                       0.0.7
# fastjsonschema                     2.21.1
# fastprogress                       1.0.3
# fastrlock                          0.8.2
# filelock                           3.16.1
# firebase-admin                     6.5.0
# Flask                              3.0.3
# flatbuffers                        24.3.25
# flax                               0.8.5
# folium                             0.18.0
# fonttools                          4.55.0
# frozendict                         2.4.6
# frozenlist                         1.5.0
# fsspec                             2024.10.0
# future                             1.0.0
# gast                               0.6.0
# gcsfs                              2024.10.0
# GDAL                               3.6.4
# gdown                              5.2.0
# geemap                             0.35.1
# gensim                             4.3.3
# geocoder                           1.38.1
# geographiclib                      2.0
# geopandas                          1.0.1
# geopy                              2.4.1
# gin-config                         0.5.0
# gitdb                              4.0.11
# GitPython                          3.1.43
# glob2                              0.7
# google                             2.0.3
# google-ai-generativelanguage       0.6.10
# google-api-core                    2.19.2
# google-api-python-client           2.151.0
# google-auth                        2.27.0
# google-auth-httplib2               0.2.0
# google-auth-oauthlib               1.2.1
# google-cloud-aiplatform            1.71.1
# google-cloud-bigquery              3.25.0
# google-cloud-bigquery-connection   1.16.1
# google-cloud-bigquery-storage      2.27.0
# google-cloud-bigtable              2.27.0
# google-cloud-core                  2.4.1
# google-cloud-datastore             2.20.1
# google-cloud-firestore             2.19.0
# google-cloud-functions             1.18.1
# google-cloud-iam                   2.16.1
# google-cloud-language              2.15.1
# google-cloud-pubsub                2.27.1
# google-cloud-resource-manager      1.13.1
# google-cloud-storage               2.8.0
# google-cloud-translate             3.17.0
# google-colab                       1.0.0
# google-crc32c                      1.6.0
# google-generativeai                0.8.3
# google-pasta                       0.2.0
# google-resumable-media             2.7.2
# googleapis-common-protos           1.66.0
# googledrivedownloader              0.4
# graphviz                           0.20.3
# greenlet                           3.1.1
# grpc-google-iam-v1                 0.13.1
# grpcio                             1.68.1
# grpcio-status                      1.62.3
# gspread                            6.0.2
# gspread-dataframe                  3.3.1
# gym                                0.25.2
# gym-notices                        0.0.8
# h11                                0.14.0
# h5netcdf                           1.4.1
# h5py                               3.12.1
# holidays                           0.62
# holoviews                          1.20.0
# html5lib                           1.1
# httpcore                           1.0.7
# httpimport                         1.4.0
# httplib2                           0.22.0
# httpx                              0.28.0
# huggingface-hub                    0.26.3
# humanize                           4.11.0
# hyperopt                           0.2.7
# ibis-framework                     9.2.0
# idna                               3.10
# imageio                            2.36.1
# imageio-ffmpeg                     0.5.1
# imagesize                          1.4.1
# imbalanced-learn                   0.12.4
# imgaug                             0.4.0
# immutabledict                      4.2.1
# importlib_metadata                 8.5.0
# importlib_resources                6.4.5
# imutils                            0.5.4
# inflect                            7.4.0
# iniconfig                          2.0.0
# intel-cmplr-lib-ur                 2025.0.3
# intel-openmp                       2025.0.3
# ipyevents                          2.0.2
# ipyfilechooser                     0.6.0
# ipykernel                          5.5.6
# ipyleaflet                         0.19.2
# ipyparallel                        8.8.0
# ipython                            7.34.0
# ipython-genutils                   0.2.0
# ipython-sql                        0.5.0
# ipytree                            0.2.2
# ipywidgets                         7.7.1
# itsdangerous                       2.2.0
# jax                                0.4.33
# jax-cuda12-pjrt                    0.4.33
# jax-cuda12-plugin                  0.4.33
# jaxlib                             0.4.33
# jeepney                            0.7.1
# jellyfish                          1.1.0
# jieba                              0.42.1
# Jinja2                             3.1.4
# jiter                              0.8.0
# joblib                             1.4.2
# jsonpatch                          1.33
# jsonpickle                         4.0.0
# jsonpointer                        3.0.0
# jsonschema                         4.23.0
# jsonschema-specifications          2024.10.1
# jupyter-client                     6.1.12
# jupyter-console                    6.1.0
# jupyter_core                       5.7.2
# jupyter-leaflet                    0.19.2
# jupyter-server                     1.24.0
# jupyterlab_pygments                0.3.0
# jupyterlab_widgets                 3.0.13
# kaggle                             1.6.17
# kagglehub                          0.3.4
# keras                              3.5.0
# keyring                            23.5.0
# kiwisolver                         1.4.7
# langchain                          0.3.9
# langchain-core                     0.3.21
# langchain-text-splitters           0.3.2
# langcodes                          3.5.0
# langsmith                          0.1.147
# language_data                      1.3.0
# launchpadlib                       1.10.16
# lazr.restfulclient                 0.14.4
# lazr.uri                           1.0.6
# lazy_loader                        0.4
# libclang                           18.1.1
# libcudf-cu12                       24.10.1
# librosa                            0.10.2.post1
# lightgbm                           4.5.0
# linkify-it-py                      2.0.3
# llvmlite                           0.43.0
# locket                             1.0.0
# logical-unification                0.4.6
# lxml                               5.3.0
# marisa-trie                        1.2.1
# Markdown                           3.7
# markdown-it-py                     3.0.0
# MarkupSafe                         3.0.2
# matplotlib                         3.8.0
# matplotlib-inline                  0.1.7
# matplotlib-venn                    1.1.1
# mdit-py-plugins                    0.4.2
# mdurl                              0.1.2
# miniKanren                         1.0.3
# missingno                          0.5.2
# mistune                            3.0.2
# mizani                             0.13.0
# mkl                                2025.0.1
# ml-dtypes                          0.4.1
# mlxtend                            0.23.3
# more-itertools                     10.5.0
# moviepy                            1.0.3
# mpmath                             1.3.0
# msgpack                            1.1.0
# multidict                          6.1.0
# multipledispatch                   1.0.0
# multitasking                       0.0.11
# murmurhash                         1.0.11
# music21                            9.3.0
# namex                              0.0.8
# natsort                            8.4.0
# nbclassic                          1.1.0
# nbclient                           0.10.1
# nbconvert                          7.16.4
# nbformat                           5.10.4
# ndindex                            1.9.2
# nest-asyncio                       1.6.0
# networkx                           3.4.2
# nibabel                            5.3.2
# nltk                               3.9.1
# notebook                           6.5.5
# notebook_shim                      0.2.4
# numba                              0.60.0
# numexpr                            2.10.2
# numpy                              1.26.4
# nvidia-cublas-cu12                 12.6.4.1
# nvidia-cuda-cupti-cu12             12.6.80
# nvidia-cuda-nvcc-cu12              12.6.85
# nvidia-cuda-runtime-cu12           12.6.77
# nvidia-cudnn-cu12                  9.5.1.17
# nvidia-cufft-cu12                  11.3.0.4
# nvidia-curand-cu12                 10.3.7.77
# nvidia-cusolver-cu12               11.7.1.2
# nvidia-cusparse-cu12               12.5.4.2
# nvidia-nccl-cu12                   2.23.4
# nvidia-nvjitlink-cu12              12.6.85
# nvtx                               0.2.10
# nx-cugraph-cu12                    24.10.0
# oauth2client                       4.1.3
# oauthlib                           3.2.2
# openai                             1.54.5
# opencv-contrib-python              4.10.0.84
# opencv-python                      4.10.0.84
# opencv-python-headless             4.10.0.84
# openpyxl                           3.1.5
# opentelemetry-api                  1.28.2
# opentelemetry-sdk                  1.28.2
# opentelemetry-semantic-conventions 0.49b2
# opt_einsum                         3.4.0
# optax                              0.2.4
# optree                             0.13.1
# orbax-checkpoint                   0.6.4
# orjson                             3.10.12
# osqp                               0.6.7.post3
# packaging                          24.2
# pandas                             2.2.2
# pandas-datareader                  0.10.0
# pandas-gbq                         0.24.0
# pandas-stubs                       2.2.2.240909
# pandocfilters                      1.5.1
# panel                              1.5.4
# param                              2.1.1
# parso                              0.8.4
# parsy                              2.1
# partd                              1.4.2
# pathlib                            1.0.1
# patsy                              1.0.1
# peewee                             3.17.8
# peft                               0.13.2
# pexpect                            4.9.0
# pickleshare                        0.7.5
# pillow                             11.0.0
# pip                                24.1.2
# platformdirs                       4.3.6
# plotly                             5.24.1
# plotnine                           0.14.3
# pluggy                             1.5.0
# ply                                3.11
# polars                             1.9.0
# pooch                              1.8.2
# portpicker                         1.5.2
# preshed                            3.0.9
# prettytable                        3.12.0
# proglog                            0.1.10
# progressbar2                       4.5.0
# prometheus_client                  0.21.0
# promise                            2.3
# prompt_toolkit                     3.0.48
# propcache                          0.2.1
# prophet                            1.1.6
# proto-plus                         1.25.0
# protobuf                           4.25.5
# psutil                             5.9.5
# psycopg2                           2.9.10
# ptyprocess                         0.7.0
# py-cpuinfo                         9.0.0
# py4j                               0.10.9.7
# pyarrow                            17.0.0
# pyarrow-hotfix                     0.6
# pyasn1                             0.6.1
# pyasn1_modules                     0.4.1
# pycocotools                        2.0.8
# pycparser                          2.22
# pydantic                           2.10.2
# pydantic_core                      2.27.1
# pydata-google-auth                 1.9.0
# pydot                              3.0.3
# pydotplus                          2.0.2
# PyDrive                            1.3.1
# PyDrive2                           1.21.3
# pyerfa                             2.0.1.5
# pygame                             2.6.1
# pygit2                             1.16.0
# Pygments                           2.18.0
# PyGObject                          3.42.1
# PyJWT                              2.10.1
# pylibcudf-cu12                     24.10.1
# pylibcugraph-cu12                  24.10.0
# pylibraft-cu12                     24.10.0
# pymc                               5.18.2
# pymystem3                          0.2.0
# pynvjitlink-cu12                   0.4.0
# pyogrio                            0.10.0
# Pyomo                              6.8.2
# PyOpenGL                           3.1.7
# pyOpenSSL                          24.2.1
# pyparsing                          3.2.0
# pyperclip                          1.9.0
# pyproj                             3.7.0
# pyshp                              2.3.1
# PySocks                            1.7.1
# pyspark                            3.5.3
# pytensor                           2.26.3
# pytest                             8.3.4
# python-apt                         0.0.0
# python-box                         7.2.0
# python-dateutil                    2.8.2
# python-louvain                     0.16
# python-slugify                     8.0.4
# python-utils                       3.9.1
# pytz                               2024.2
# pyviz_comms                        3.0.3
# PyYAML                             6.0.2
# pyzmq                              24.0.1
# qdldl                              0.1.7.post4
# ratelim                            0.1.6
# referencing                        0.35.1
# regex                              2024.9.11
# requests                           2.32.3
# requests-oauthlib                  1.3.1
# requests-toolbelt                  1.0.0
# requirements-parser                0.9.0
# rich                               13.9.4
# rmm-cu12                           24.10.0
# rpds-py                            0.22.0
# rpy2                               3.4.2
# rsa                                4.9
# safetensors                        0.4.5
# scikit-image                       0.24.0
# scikit-learn                       1.5.2
# scipy                              1.13.1
# scooby                             0.10.0
# scs                                3.2.7
# seaborn                            0.13.2
# SecretStorage                      3.3.1
# Send2Trash                         1.8.3
# sentence-transformers              3.2.1
# sentencepiece                      0.2.0
# sentry-sdk                         2.19.0
# setproctitle                       1.3.4
# setuptools                         75.1.0
# shap                               0.46.0
# shapely                            2.0.6
# shellingham                        1.5.4
# simple-parsing                     0.1.6
# six                                1.16.0
# sklearn-pandas                     2.2.0
# slicer                             0.0.8
# smart-open                         7.0.5
# smmap                              5.0.1
# sniffio                            1.3.1
# snowballstemmer                    2.2.0
# soundfile                          0.12.1
# soupsieve                          2.6
# soxr                               0.5.0.post1
# spacy                              3.7.5
# spacy-legacy                       3.0.12
# spacy-loggers                      1.0.5
# Sphinx                             8.1.3
# sphinxcontrib-applehelp            2.0.0
# sphinxcontrib-devhelp              2.0.0
# sphinxcontrib-htmlhelp             2.1.0
# sphinxcontrib-jsmath               1.0.1
# sphinxcontrib-qthelp               2.0.0
# sphinxcontrib-serializinghtml      2.0.0
# SQLAlchemy                         2.0.36
# sqlglot                            25.1.0
# sqlparse                           0.5.2
# srsly                              2.4.8
# stanio                             0.5.1
# statsmodels                        0.14.4
# StrEnum                            0.4.15
# stringzilla                        3.11.0
# sympy                              1.13.1
# tables                             3.10.1
# tabulate                           0.9.0
# tbb                                2022.0.0
# tcmlib                             1.2.0
# tenacity                           9.0.0
# tensorboard                        2.17.1
# tensorboard-data-server            0.7.2
# tensorflow                         2.17.1
# tensorflow-datasets                4.9.7
# tensorflow-hub                     0.16.1
# tensorflow-io-gcs-filesystem       0.37.1
# tensorflow-metadata                1.13.1
# tensorflow-probability             0.24.0
# tensorstore                        0.1.69
# termcolor                          2.5.0
# terminado                          0.18.1
# text-unidecode                     1.3
# textblob                           0.17.1
# tf_keras                           2.17.0
# tf-slim                            1.1.0
# thinc                              8.2.5
# threadpoolctl                      3.5.0
# tifffile                           2024.9.20
# timm                               1.0.11
# tinycss2                           1.4.0
# tokenizers                         0.20.3
# toml                               0.10.2
# tomli                              2.2.1
# toolz                              0.12.1
# torch                              2.5.1+cu121
# torchaudio                         2.5.1+cu121
# torchsummary                       1.5.1
# torchvision                        0.20.1+cu121
# tornado                            6.3.3
# tqdm                               4.66.6
# traitlets                          5.7.1
# traittypes                         0.2.1
# transformers                       4.46.3
# tweepy                             4.14.0
# typeguard                          4.4.1
# typer                              0.14.0
# types-pytz                         2024.2.0.20241003
# types-setuptools                   75.6.0.20241126
# typing                             3.7.4.3
# typing_extensions                  4.12.2
# tzdata                             2024.2
# tzlocal                            5.2
# uc-micro-py                        1.0.3
# umf                                0.9.1
# uritemplate                        4.1.1
# urllib3                            2.2.3
# vega-datasets                      0.9.0
# wadllib                            1.3.6
# wandb                              0.18.7
# wasabi                             1.1.3
# wcwidth                            0.2.13
# weasel                             0.4.1
# webcolors                          24.11.1
# webencodings                       0.5.1
# websocket-client                   1.8.0
# Werkzeug                           3.1.3
# wheel                              0.45.1
# widgetsnbextension                 3.6.10
# wordcloud                          1.9.4
# wrapt                              1.17.0
# xarray                             2024.10.0
# xarray-einstats                    0.8.0
# xgboost                            2.1.3
# xlrd                               2.0.1
# xyzservices                        2024.9.0
# yarl                               1.18.3
# yellowbrick                        1.5
# yfinance                           0.2.50
# zipp                               3.21.0

# %%
# %%writefile train.py

import torch
import torch.nn as nn
from torch.nn import functional as nnf
from torch.utils.data import Dataset, DataLoader
from enum import Enum
from transformers import GPT2Tokenizer, GPT2LMHeadModel, AdamW, get_linear_schedule_with_warmup
from tqdm import tqdm
import os
import pickle
import sys
import argparse
import json, math
from typing import Tuple, Optional, Union

device = torch.device('cuda:0')


def get_uniform_ball_noise(input_shape, radius=0.1):
    uniform_noise_ball = torch.randn(input_shape, device=device)  # normal distribution
    uniform_noise_sphere = torch.nn.functional.normalize(uniform_noise_ball, dim=1)
    u = torch.rand(input_shape[0], device=device)  # unified distribution
    u = u ** (1. / input_shape[1])
    uniform_noise_ball = (uniform_noise_sphere.T * u * radius).T
    return uniform_noise_ball


def noise_injection(x, variance=0.001, modality_offset=None, uniform_noise=False, dont_norm=False):
    if variance == 0.0:
        return x
    std = math.sqrt(variance)
    if not dont_norm:
        x = torch.nn.functional.normalize(x, dim=1)
    if uniform_noise:
        x = x + get_uniform_ball_noise(x.shape, radius=std)
    else:
        x = x + (torch.randn(x.shape, device=device) * std)  # todo by some conventions multivraiance noise should be devided by sqrt of dim
    if modality_offset is not None:
        x = x + modality_offset
    return torch.nn.functional.normalize(x, dim=1)


class MappingType(Enum):
    MLP = 'mlp'
    Transformer = 'transformer'


class ClipCocoDataset(Dataset):
    def __len__(self) -> int:
        return len(self.captions_tokens)

    def pad_tokens(self, item: int):
        tokens = self.captions_tokens[item]
        padding = self.max_seq_len - tokens.shape[0]
        if padding > 0:
            tokens = torch.cat((tokens, torch.zeros(padding, dtype=torch.int64) - 1))
            self.captions_tokens[item] = tokens
        elif padding < 0:
            tokens = tokens[:self.max_seq_len]
            self.captions_tokens[item] = tokens
        mask = tokens.ge(0)  # mask is zero where we out of sequence
        tokens[~mask] = 0
        mask = mask.float()
        mask = torch.cat((torch.ones(self.prefix_length), mask), dim=0)  # adding prefix mask
        return tokens, mask

    def __getitem__(self, item: int) -> Tuple[torch.Tensor, ...]:
        tokens, mask = self.pad_tokens(item)
        print("Length of prefixes:", len(self.prefixes))
        print("caption2embedding:", self.caption2embedding[item])
        print("Item index:", item)
        prefix = self.prefixes[self.caption2embedding[item]]
        if self.normalize_prefix:
            prefix = prefix.float()
            prefix = prefix / prefix.norm(2, -1)

        return tokens, mask, prefix

    def __init__(self, data_path: str,  prefix_length: int, gpt2_type: str = "gpt2",
                 normalize_prefix=False, use_image_embedding_as_clipcap=False):
        self.tokenizer = GPT2Tokenizer.from_pretrained(gpt2_type)
        self.prefix_length = prefix_length
        self.normalize_prefix = normalize_prefix
        with open(data_path, 'rb') as f:
            all_data = pickle.load(f)
        print(all_data)
        print(all_data.keys())
        print("Data size is %0d" % len(all_data["clip_embedding" if use_image_embedding_as_clipcap else "clip_embedding_text_dave"]))
        sys.stdout.flush()
        self.prefixes = all_data["clip_embedding" if use_image_embedding_as_clipcap else "clip_embedding_text_dave"]
        captions_raw = all_data["captions"]
        self.image_ids = [caption["image_id"] for caption in captions_raw]
        self.captions = [caption['caption'] for caption in captions_raw]
        if os.path.isfile(f"{data_path[:-4]}_tokens.pkl"):
            with open(f"{data_path[:-4]}_tokens.pkl", 'rb') as f:
                self.captions_tokens, self.caption2embedding, self.max_seq_len = pickle.load(f)
        else:
            self.captions_tokens = []
            self.caption2embedding = []
            max_seq_len = 0
            for caption in captions_raw:
                self.captions_tokens.append(torch.tensor(self.tokenizer.encode(caption['caption']), dtype=torch.int64))
                self.caption2embedding.append(caption["clip_embedding"])
                max_seq_len = max(max_seq_len, self.captions_tokens[-1].shape[0])
            # self.max_seq_len = max_seq_len
            with open(f"{data_path[:-4]}_tokens.pkl", 'wb') as f:
                pickle.dump([self.captions_tokens, self.caption2embedding, max_seq_len], f)
        all_len = torch.tensor([len(self.captions_tokens[i]) for i in range(len(self))]).float()
        self.max_seq_len = min(int(all_len.mean() + all_len.std() * 10), int(all_len.max()))


class MLP(nn.Module):

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        return self.model(x)

    def __init__(self, sizes: Tuple[int, ...], bias=True, act=nn.Tanh):
        super(MLP, self).__init__()
        layers = []
        for i in range(len(sizes) - 1):
            layers.append(nn.Linear(sizes[i], sizes[i + 1], bias=bias))
            if i < len(sizes) - 2:
                layers.append(act())
        self.model = nn.Sequential(*layers)


class MlpTransformer(nn.Module):
    def __init__(self, in_dim, h_dim, out_d: Optional[int] = None, act=nnf.relu, dropout=0.):
        super().__init__()
        out_d = out_d if out_d is not None else in_dim
        self.fc1 = nn.Linear(in_dim, h_dim)
        self.act = act
        self.fc2 = nn.Linear(h_dim, out_d)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        x = self.fc1(x)
        x = self.act(x)
        x = self.dropout(x)
        x = self.fc2(x)
        x = self.dropout(x)
        return x

class MultiHeadAttention(nn.Module):

    def __init__(self, dim_self, dim_ref, num_heads, bias=True, dropout=0.):
        super().__init__()
        self.num_heads = num_heads
        head_dim = dim_self // num_heads
        self.scale = head_dim ** -0.5
        self.to_queries = nn.Linear(dim_self, dim_self, bias=bias)
        self.to_keys_values = nn.Linear(dim_ref, dim_self * 2, bias=bias)
        self.project = nn.Linear(dim_self, dim_self)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, y=None, mask=None):
        y = y if y is not None else x
        b, n, c = x.shape
        _, m, d = y.shape
        # b n h dh
        queries = self.to_queries(x).reshape(b, n, self.num_heads, c // self.num_heads)
        # b m 2 h dh
        keys_values = self.to_keys_values(y).reshape(b, m, 2, self.num_heads, c // self.num_heads)
        keys, values = keys_values[:, :, 0], keys_values[:, :, 1]
        attention = torch.einsum('bnhd,bmhd->bnmh', queries, keys) * self.scale
        if mask is not None:
            if mask.dim() == 2:
                mask = mask.unsqueeze(1)
            attention = attention.masked_fill(mask.unsqueeze(3), float("-inf"))
        attention = attention.softmax(dim=2)
        out = torch.einsum('bnmh,bmhd->bnhd', attention, values).reshape(b, n, c)
        out = self.project(out)
        return out, attention


class TransformerLayer(nn.Module):

    def forward_with_attention(self, x, y=None, mask=None):
        x_, attention = self.attn(self.norm1(x), y, mask)
        x = x + x_
        x = x + self.mlp(self.norm2(x))
        return x, attention

    def forward(self, x, y=None, mask=None):
        x = x + self.attn(self.norm1(x), y, mask)[0]
        x = x + self.mlp(self.norm2(x))
        return x

    def __init__(self, dim_self, dim_ref, num_heads, mlp_ratio=4., bias=False, dropout=0., act=nnf.relu,
                 norm_layer: nn.Module = nn.LayerNorm):
        super().__init__()
        self.norm1 = norm_layer(dim_self)
        self.attn = MultiHeadAttention(dim_self, dim_ref, num_heads, bias=bias, dropout=dropout)
        self.norm2 = norm_layer(dim_self)
        self.mlp = MlpTransformer(dim_self, int(dim_self * mlp_ratio), act=act, dropout=dropout)


class Transformer(nn.Module):

    def forward_with_attention(self, x, y=None, mask=None):
        attentions = []
        for layer in self.layers:
            x, att = layer.forward_with_attention(x, y, mask)
            attentions.append(att)
        return x, attentions

    def forward(self, x, y=None, mask=None):
        for i, layer in enumerate(self.layers):
            if i % 2 == 0 and self.enc_dec: # cross
                x = layer(x, y)
            elif self.enc_dec:  # self
                x = layer(x, x, mask)
            else:  # self or cross
                x = layer(x, y, mask)
        return x

    def __init__(self, dim_self: int, num_heads: int, num_layers: int, dim_ref: Optional[int] = None,
                 mlp_ratio: float = 2., act=nnf.relu, norm_layer: nn.Module = nn.LayerNorm, enc_dec: bool = False):
        super(Transformer, self).__init__()
        dim_ref = dim_ref if dim_ref is not None else dim_self
        self.enc_dec = enc_dec
        if enc_dec:
            num_layers = num_layers * 2
        layers = []
        for i in range(num_layers):
            if i % 2 == 0 and enc_dec:  # cross
                layers.append(TransformerLayer(dim_self, dim_ref, num_heads, mlp_ratio, act=act, norm_layer=norm_layer))
            elif enc_dec:  # self
                layers.append(TransformerLayer(dim_self, dim_self, num_heads, mlp_ratio, act=act, norm_layer=norm_layer))
            else:  # self or cross
                layers.append(TransformerLayer(dim_self, dim_ref, num_heads, mlp_ratio, act=act, norm_layer=norm_layer))
        self.layers = nn.ModuleList(layers)


class TransformerMapper(nn.Module):

    def forward(self, x):
        x = self.linear(x).view(x.shape[0], self.clip_length, -1)
        prefix = self.prefix_const.unsqueeze(0).expand(x.shape[0], *self.prefix_const.shape)
        prefix = torch.cat((x, prefix), dim=1)
        out = self.transformer(prefix)[:, self.clip_length:]
        return out

    def __init__(self, dim_clip: int, dim_embedding: int, prefix_length: int, clip_length: int, num_layers: int = 8):
        super(TransformerMapper, self).__init__()
        self.clip_length = clip_length
        self.transformer = Transformer(dim_embedding, 8, num_layers)
        self.linear = nn.Linear(dim_clip, clip_length * dim_embedding)
        self.prefix_const = nn.Parameter(torch.randn(prefix_length, dim_embedding), requires_grad=True)


class ClipCaptionModel(nn.Module):

    def get_dummy_token(self, batch_size: int, device: torch.device) -> torch.Tensor:
        return torch.zeros(batch_size, self.prefix_length, dtype=torch.int64, device=device)

    def forward(self, tokens: torch.Tensor, prefix: torch.Tensor, mask: Optional[torch.Tensor] = None,
                labels: Optional[torch.Tensor] = None):
        embedding_text = self.gpt.transformer.wte(tokens)
        prefix_projections = self.clip_project(prefix).view(-1, self.prefix_length, self.gpt_embedding_size)
        embedding_cat = torch.cat((prefix_projections, embedding_text), dim=1)
        if labels is not None:
            dummy_token = self.get_dummy_token(tokens.shape[0], tokens.device)
            labels = torch.cat((dummy_token, tokens), dim=1)
        out = self.gpt(inputs_embeds=embedding_cat, labels=labels, attention_mask=mask)
        return out

    def __init__(self, prefix_length: int, clip_length: Optional[int] = None, prefix_size: int = 512,
                 num_layers: int = 8, mapping_type: MappingType = MappingType.MLP):
        super(ClipCaptionModel, self).__init__()
        self.prefix_length = prefix_length
        self.gpt = GPT2LMHeadModel.from_pretrained('gpt2')
        self.gpt_embedding_size = self.gpt.transformer.wte.weight.shape[1]
        if mapping_type == MappingType.MLP:
            self.clip_project = MLP((prefix_size, (self.gpt_embedding_size * prefix_length) // 2,
                                     self.gpt_embedding_size * prefix_length))
        else:
            self.clip_project = TransformerMapper(prefix_size, self.gpt_embedding_size, prefix_length,
                                                                     clip_length, num_layers)


class ClipCaptionPrefix(ClipCaptionModel):

    def parameters(self, recurse: bool = True):
        return self.clip_project.parameters()

    def train(self, mode: bool = True):
        super(ClipCaptionPrefix, self).train(mode)
        self.gpt.eval()
        return self


def save_config(args: argparse.Namespace):
    config = {}
    for key, item in args._get_kwargs():
        config[key] = item
    out_path = os.path.join(args.out_dir, f"{args.prefix}.json")
    with open(out_path, 'w') as outfile:
        json.dump(config, outfile)


def load_model(config_path: str, epoch_or_latest: Union[str, int] = '_latest'):
    with open(config_path) as f:
        config = json.load(f)
    parser = argparse.ArgumentParser()
    parser.set_defaults(**config)
    args = parser.parse_args()
    if type(epoch_or_latest) is int:
        epoch_or_latest = f"-{epoch_or_latest:03d}"
    model_path = os.path.join(args.out_dir, f"{args.prefix}{epoch_or_latest}.pt")
    if args.only_prefix:
        model = ClipCaptionPrefix(args.prefix_length)
    else:
        model = ClipCaptionModel(args.prefix_length)
    if os.path.isfile(model_path):
        print(f"loading model from {model_path}")
        model.load_state_dict(torch.load(model_path, map_location=torch.device('cpu')))
    else:
        print(f"{model_path} is not exist")
    return model, parser


def train(dataset: ClipCocoDataset, model: ClipCaptionModel, args, warmup_steps: int = 5000, output_dir: str = ".", output_prefix: str = ""):

    device = torch.device('cuda:0')
    batch_size = args.bs
    epochs = args.epochs
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    model = model.to(device)
    model.train()
    optimizer = AdamW(model.parameters(), lr=args.lr)
    train_dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True, drop_last=True)
    scheduler = get_linear_schedule_with_warmup(
        optimizer, num_warmup_steps=warmup_steps, num_training_steps=epochs * len(train_dataloader)
    )

    if args.add_modality_offset:
        with open('others/CLIP_embeddings_centers_info.pkl', 'rb') as f:
            modality_offset = pickle.load(f)['offset_to_add_in_training'].to(device)
    else:
        modality_offset = None
    loss_per_epoch_train = []
    loss_per_epoch_val = []
    for epoch in range(epochs):
        print(f">>> Training epoch {epoch} / {epochs}")
        sys.stdout.flush()
        progress = tqdm(total=len(train_dataloader), desc=output_prefix)
        accumulated_loss = 0.0
        for idx, (tokens, mask, prefix) in enumerate(train_dataloader):
            model.zero_grad()
            tokens, mask, prefix = tokens.to(device), mask.to(device), prefix.to(device, dtype=torch.float32)
            prefix = noise_injection(prefix, args.noise_variance, modality_offset=modality_offset, uniform_noise=args.uniform_noise, dont_norm=args.dont_norm)
            outputs = model(tokens, prefix, mask)
            logits = outputs.logits[:, dataset.prefix_length - 1: -1]
            loss = nnf.cross_entropy(logits.reshape(-1, logits.shape[-1]), tokens.flatten(), ignore_index=0)
            loss.backward()
            optimizer.step()
            scheduler.step()
            optimizer.zero_grad()
            loss_value = loss.item()
            progress.set_postfix({"loss": loss_value})
            progress.update()
            accumulated_loss += loss_value
            if (idx + 1) % 10000 == 0:
                torch.save(
                    model.state_dict(),
                    os.path.join(output_dir, f"{output_prefix}_latest.pt"),
                )
        progress.close()
        loss_per_epoch_train.append(accumulated_loss / len(train_dataloader))
        print('loss_per_epoch_train: ', loss_per_epoch_train)
        if epoch % args.save_every == 0 or epoch == epochs - 1:
            torch.save(
                model.state_dict(),
                os.path.join(output_dir, f"{output_prefix}-{epoch:03d}.pt"),
            )
        if args.val_pt:
            val_dataset = ClipCocoDataset(args.val_pt, args.prefix_length, normalize_prefix=not args.dont_norm,
                            use_image_embedding_as_clipcap=args.use_image_embedding_as_clipcap)

            val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=True, drop_last=True)
            val_loss = 0.0
            model.eval()
            with torch.no_grad():
                torch.cuda.empty_cache()
                for idx, (tokens, mask, prefix) in enumerate(val_dataloader):
                    tokens, mask, prefix = tokens.to(device), mask.to(device), prefix.to(device, dtype=torch.float32)
                    outputs = model(tokens, prefix, mask)
                    logits = outputs.logits[:, dataset.prefix_length - 1: -1]
                    loss = nnf.cross_entropy(logits.reshape(-1, logits.shape[-1]), tokens.flatten(), ignore_index=0)
                    val_loss += loss.item()
            model.train()
            loss_per_epoch_val.append(val_loss / len(val_dataloader))
            print('loss_per_epoch_val: ', loss_per_epoch_val)
        with open(os.path.join(output_dir, f"loss_per_epoch.json"), 'w') as f:
            json.dump({'train': loss_per_epoch_train, 'val': loss_per_epoch_val}, f)
    return model


def main():
    parser = argparse.ArgumentParser()
    parser.add_argument('--data', default='clip_embedding.pkl', help='path to clip embeddings of captions generated by the attached embeddings_generator script')
    parser.add_argument('--val_pt', default='', help='path to clip embeddings of validations set')
    parser.add_argument('--pretrain_weights', default='', help='path to pretrained weights, if not specified, will train from scratch')
    parser.add_argument('--out_dir', default='./checkpoints', help='path to output directory')
    parser.add_argument('--add_modality_offset', dest='add_modality_offset', action='store_true', default=False, help='train with modality offset that was pre calculated at others/CLIP_embeddings_centers_info.pkl')
    parser.add_argument('--prefix', default='coco_prefix', help='prefix for saved filenames')
    parser.add_argument('--noise_variance', type=float, default=0.0, help='noise variance')
    parser.add_argument('--uniform_noise', dest='uniform_noise', action='store_true', default=False, help='use uniform noise instead of gaussian')
    parser.add_argument('--dont_norm', dest='dont_norm', action='store_true', default=False, help='dont normalize CLIP embeddings')
    parser.add_argument('--lr', type=float, default=2e-5, help='learning rate')
    parser.add_argument('--epochs', type=int, default=10, help='number of epochs')
    parser.add_argument('--save_every', type=int, default=1, help='save every n epochs')
    parser.add_argument('--prefix_length', type=int, default=40, help='prefix length')
    parser.add_argument('--prefix_length_clip', type=int, default=40, help='prefix length for clip')
    parser.add_argument('--bs', type=int, default=34, help='batch size')
    parser.add_argument('--only_prefix', dest='only_prefix', action='store_true', default=False, help='train only the mapper between CLIP and GPT, while GPT is frozen')
    parser.add_argument('--mapping_type', type=str, default='transformer', help='type of architurctre between CLIP and GPT (mlp/transformer)')
    parser.add_argument('--num_layers', type=int, default=8, help='number of layers in the mapper')
    parser.add_argument('--is_not_rn', dest='is_not_rn', action='store_true', default=False, help='Choose the CLIP backbone: False for RN, True for ViT')
    parser.add_argument('--use_image_embedding_as_clipcap', dest='use_image_embedding_as_clipcap', action='store_true', default=False, help='use image embedding as ClipCap')
    args = parser.parse_args()
    if args.data == 'COCO':
        args.bs = 30
        if args.use_image_embedding_as_clipcap:
            args.data = './data/coco/oscar_split_RN50x4_train_with_text_embeddings.pkl'
            args.val_pt = ''  # not used
        else:
            args.data = './data/flicker30_RN50x4_train_with_text_embeddings_not_norm.pkl'
            args.val_pt = './data/flicker30_RN50x4_val_with_text_embeddings_not_norm.pkl'
        if args.dont_norm:
            args.data = './data/coco/verified_split_COCO_train_set_with_text_not_norm.pkl'
            args.val_pt = ''
    elif args.data == 'FLICKR':
        args.bs = 16
        if args.use_image_embedding_as_clipcap:
            args.data = './data/flicker30_RN50x4_train_with_text_embeddings_not_norm.pkl'
            args.val_pt = ''  # not used
        else:
          ##########################################
          # EDIT DIRECTORY HERE - POINTS TO IMAGE EMBEDDINGS
          ##########################################
            args.data = '/content/flicker30_RN50x4_train_with_text_embeddings_not_norm.pkl'
            args.val_pt = '/content/flicker30_RN50x4_val_with_text_embeddings_not_norm.pkl'
        if args.dont_norm:
            if args.use_image_embedding_as_clipcap:
                exit('NONORM is not supported yet with use_image_embedding_as_clipcap')
            else:
                args.data = './data/flicker30_RN50x4_train_with_text_embeddings_not_norm.pkl'
                args.val_pt = ''
    prefix_length = args.prefix_length
    dataset = ClipCocoDataset(args.data, prefix_length, normalize_prefix=not args.dont_norm, use_image_embedding_as_clipcap=args.use_image_embedding_as_clipcap)

    prefix_dim = 640 if not args.is_not_rn else 512
    args.mapping_type = {'mlp': MappingType.MLP, 'transformer': MappingType.Transformer}[args.mapping_type]
    if args.only_prefix:
        model = ClipCaptionPrefix(prefix_length, clip_length=args.prefix_length_clip, prefix_size=prefix_dim,
                                  num_layers=args.num_layers, mapping_type=args.mapping_type)
        print("Train only prefix")
    else:
        model = ClipCaptionModel(prefix_length, clip_length=args.prefix_length_clip, prefix_size=prefix_dim,
                                  num_layers=args.num_layers, mapping_type=args.mapping_type)
        print("Train both prefix and GPT")
        sys.stdout.flush()
    if args.pretrain_weights != '':
        model.load_state_dict(torch.load(args.pretrain_weights, map_location=device))
    print(f'modality_offset={args.add_modality_offset}')
    from pathlib import Path
    Path(args.out_dir).mkdir(parents=True, exist_ok=True)
    directory = os.path.dirname(args.out_dir)
    if not os.path.exists(directory):
      os.makedirs(directory)
    with open(f'{args.out_dir}/train_commandline_args.txt', 'w') as f:
        args_at_dict = args.__dict__
        args_at_dict.pop('mapping_type')
        json.dump(dict(args_at_dict), f, indent=2)
        print(f'args saved to file {args.out_dir}/train_commandline_args.txt')
    train(dataset, model, args, output_dir=args.out_dir, output_prefix=args.prefix)


if __name__ == '__main__':
    main()
# Out:
# Writing train.py

# %% [markdown]
# Training from scratch

# %%
# !python train.py --data FLICKR --out_dir "/content/trained_models/var_0.016/" --noise_variance 0.016
# Out:
# Streaming output truncated to the last 5000 lines.
# Item index: 1129
# Length of prefixes: 14500
# caption2embedding: 4617
# Item index: 4617
# Length of prefixes: 14500
# caption2embedding: 4032
# Item index: 4032
# Length of prefixes: 14500
# caption2embedding: 5923
# Item index: 5923
# Length of prefixes: 14500
# caption2embedding: 14483
# Item index: 14483
# Length of prefixes: 14500
# caption2embedding: 8910
# Item index: 8910
# Length of prefixes: 14500
# caption2embedding: 4287
# Item index: 4287
# Length of prefixes: 14500
# caption2embedding: 1464
# Item index: 1464
# Length of prefixes: 14500
# caption2embedding: 6972
# Item index: 6972
# Length of prefixes: 14500
# caption2embedding: 10380
# Item index: 10380
# Length of prefixes: 14500
# caption2embedding: 7308
# Item index: 7308
# Length of prefixes: 14500
# caption2embedding: 9555
# Item index: 9555
# Length of prefixes: 14500
# caption2embedding: 82
# Item index: 82
# Length of prefixes: 14500
# caption2embedding: 14139
# Item index: 14139
# Length of prefixes: 14500
# caption2embedding: 7203
# Item index: 7203
# coco_prefix:  92% 834/906 [07:57<00:40,  1.76it/s, loss=2.49]Length of prefixes: 14500
# caption2embedding: 5442
# Item index: 5442
# Length of prefixes: 14500
# caption2embedding: 170
# Item index: 170
# Length of prefixes: 14500
# caption2embedding: 5745
# Item index: 5745
# Length of prefixes: 14500
# caption2embedding: 8835
# Item index: 8835
# Length of prefixes: 14500
# caption2embedding: 6309
# Item index: 6309
# Length of prefixes: 14500
# caption2embedding: 4247
# Item index: 4247
# Length of prefixes: 14500
# caption2embedding: 2038
# Item index: 2038
# Length of prefixes: 14500
# caption2embedding: 4632
# Item index: 4632
# Length of prefixes: 14500
# caption2embedding: 4167
# Item index: 4167
# Length of prefixes: 14500
# caption2embedding: 1716
# Item index: 1716
# Length of prefixes: 14500
# caption2embedding: 13571
# Item index: 13571
# Length of prefixes: 14500
# caption2embedding: 13053
# Item index: 13053
# Length of prefixes: 14500
# caption2embedding: 5306
# Item index: 5306
# Length of prefixes: 14500
# caption2embedding: 2608
# Item index: 2608
# Length of prefixes: 14500
# caption2embedding: 12155
# Item index: 12155
# Length of prefixes: 14500
# caption2embedding: 13894
# Item index: 13894
# coco_prefix:  92% 835/906 [07:58<00:40,  1.76it/s, loss=2.59]Length of prefixes: 14500
# caption2embedding: 7300
# Item index: 7300
# Length of prefixes: 14500
# caption2embedding: 10313
# Item index: 10313
# Length of prefixes: 14500
# caption2embedding: 6847
# Item index: 6847
# Length of prefixes: 14500
# caption2embedding: 7253
# Item index: 7253
# Length of prefixes: 14500
# caption2embedding: 13520
# Item index: 13520
# Length of prefixes: 14500
# caption2embedding: 614
# Item index: 614
# Length of prefixes: 14500
# caption2embedding: 14484
# Item index: 14484
# Length of prefixes: 14500
# caption2embedding: 9001
# Item index: 9001
# Length of prefixes: 14500
# caption2embedding: 8645
# Item index: 8645
# Length of prefixes: 14500
# caption2embedding: 3627
# Item index: 3627
# Length of prefixes: 14500
# caption2embedding: 12736
# Item index: 12736
# Length of prefixes: 14500
# caption2embedding: 362
# Item index: 362
# Length of prefixes: 14500
# caption2embedding: 673
# Item index: 673
# Length of prefixes: 14500
# caption2embedding: 4420
# Item index: 4420
# Length of prefixes: 14500
# caption2embedding: 1003
# Item index: 1003
# Length of prefixes: 14500
# caption2embedding: 9672
# Item index: 9672
# coco_prefix:  92% 836/906 [07:58<00:39,  1.76it/s, loss=2.31]Length of prefixes: 14500
# caption2embedding: 3319
# Item index: 3319
# Length of prefixes: 14500
# caption2embedding: 3551
# Item index: 3551
# Length of prefixes: 14500
# caption2embedding: 7215
# Item index: 7215
# Length of prefixes: 14500
# caption2embedding: 6204
# Item index: 6204
# Length of prefixes: 14500
# caption2embedding: 3542
# Item index: 3542
# Length of prefixes: 14500
# caption2embedding: 3513
# Item index: 3513
# Length of prefixes: 14500
# caption2embedding: 6409
# Item index: 6409
# Length of prefixes: 14500
# caption2embedding: 12248
# Item index: 12248
# Length of prefixes: 14500
# caption2embedding: 12697
# Item index: 12697
# Length of prefixes: 14500
# caption2embedding: 13934
# Item index: 13934
# Length of prefixes: 14500
# caption2embedding: 2191
# Item index: 2191
# Length of prefixes: 14500
# caption2embedding: 8461
# Item index: 8461
# Length of prefixes: 14500
# caption2embedding: 8095
# Item index: 8095
# Length of prefixes: 14500
# caption2embedding: 8008
# Item index: 8008
# Length of prefixes: 14500
# caption2embedding: 171
# Item index: 171
# Length of prefixes: 14500
# caption2embedding: 14022
# Item index: 14022
# coco_prefix:  92% 837/906 [07:59<00:39,  1.76it/s, loss=2.4]Length of prefixes: 14500
# caption2embedding: 8965
# Item index: 8965
# Length of prefixes: 14500
# caption2embedding: 1589
# Item index: 1589
# Length of prefixes: 14500
# caption2embedding: 4614
# Item index: 4614
# Length of prefixes: 14500
# caption2embedding: 2900
# Item index: 2900
# Length of prefixes: 14500
# caption2embedding: 7723
# Item index: 7723
# Length of prefixes: 14500
# caption2embedding: 9486
# Item index: 9486
# Length of prefixes: 14500
# caption2embedding: 13702
# Item index: 13702
# Length of prefixes: 14500
# caption2embedding: 7689
# Item index: 7689
# Length of prefixes: 14500
# caption2embedding: 3287
# Item index: 3287
# Length of prefixes: 14500
# caption2embedding: 8519
# Item index: 8519
# Length of prefixes: 14500
# caption2embedding: 3159
# Item index: 3159
# Length of prefixes: 14500
# caption2embedding: 13449
# Item index: 13449
# Length of prefixes: 14500
# caption2embedding: 4574
# Item index: 4574
# Length of prefixes: 14500
# caption2embedding: 6153
# Item index: 6153
# Length of prefixes: 14500
# caption2embedding: 12953
# Item index: 12953
# Length of prefixes: 14500
# caption2embedding: 13130
# Item index: 13130
# coco_prefix:  92% 838/906 [08:00<00:38,  1.76it/s, loss=2.66]Length of prefixes: 14500
# caption2embedding: 11700
# Item index: 11700
# Length of prefixes: 14500
# caption2embedding: 4478
# Item index: 4478
# Length of prefixes: 14500
# caption2embedding: 9155
# Item index: 9155
# Length of prefixes: 14500
# caption2embedding: 2671
# Item index: 2671
# Length of prefixes: 14500
# caption2embedding: 7418
# Item index: 7418
# Length of prefixes: 14500
# caption2embedding: 7113
# Item index: 7113
# Length of prefixes: 14500
# caption2embedding: 6445
# Item index: 6445
# Length of prefixes: 14500
# caption2embedding: 7146
# Item index: 7146
# Length of prefixes: 14500
# caption2embedding: 6982
# Item index: 6982
# Length of prefixes: 14500
# caption2embedding: 11679
# Item index: 11679
# Length of prefixes: 14500
# caption2embedding: 5148
# Item index: 5148
# Length of prefixes: 14500
# caption2embedding: 4072
# Item index: 4072
# Length of prefixes: 14500
# caption2embedding: 11479
# Item index: 11479
# Length of prefixes: 14500
# caption2embedding: 9789
# Item index: 9789
# Length of prefixes: 14500
# caption2embedding: 6139
# Item index: 6139
# Length of prefixes: 14500
# caption2embedding: 8972
# Item index: 8972
# coco_prefix:  93% 839/906 [08:00<00:38,  1.75it/s, loss=2.49]Length of prefixes: 14500
# caption2embedding: 3226
# Item index: 3226
# Length of prefixes: 14500
# caption2embedding: 10282
# Item index: 10282
# Length of prefixes: 14500
# caption2embedding: 6877
# Item index: 6877
# Length of prefixes: 14500
# caption2embedding: 9167
# Item index: 9167
# Length of prefixes: 14500
# caption2embedding: 6113
# Item index: 6113
# Length of prefixes: 14500
# caption2embedding: 4398
# Item index: 4398
# Length of prefixes: 14500
# caption2embedding: 713
# Item index: 713
# Length of prefixes: 14500
# caption2embedding: 11008
# Item index: 11008
# Length of prefixes: 14500
# caption2embedding: 9501
# Item index: 9501
# Length of prefixes: 14500
# caption2embedding: 13931
# Item index: 13931
# Length of prefixes: 14500
# caption2embedding: 12048
# Item index: 12048
# Length of prefixes: 14500
# caption2embedding: 8585
# Item index: 8585
# Length of prefixes: 14500
# caption2embedding: 5881
# Item index: 5881
# Length of prefixes: 14500
# caption2embedding: 12618
# Item index: 12618
# Length of prefixes: 14500
# caption2embedding: 8735
# Item index: 8735
# Length of prefixes: 14500
# caption2embedding: 3939
# Item index: 3939
# coco_prefix:  93% 840/906 [08:01<00:37,  1.75it/s, loss=2.46]Length of prefixes: 14500
# caption2embedding: 9977
# Item index: 9977
# Length of prefixes: 14500
# caption2embedding: 2245
# Item index: 2245
# Length of prefixes: 14500
# caption2embedding: 11589
# Item index: 11589
# Length of prefixes: 14500
# caption2embedding: 12140
# Item index: 12140
# Length of prefixes: 14500
# caption2embedding: 4475
# Item index: 4475
# Length of prefixes: 14500
# caption2embedding: 6873
# Item index: 6873
# Length of prefixes: 14500
# caption2embedding: 7351
# Item index: 7351
# Length of prefixes: 14500
# caption2embedding: 11102
# Item index: 11102
# Length of prefixes: 14500
# caption2embedding: 9253
# Item index: 9253
# Length of prefixes: 14500
# caption2embedding: 6543
# Item index: 6543
# Length of prefixes: 14500
# caption2embedding: 14187
# Item index: 14187
# Length of prefixes: 14500
# caption2embedding: 3158
# Item index: 3158
# Length of prefixes: 14500
# caption2embedding: 9046
# Item index: 9046
# Length of prefixes: 14500
# caption2embedding: 11327
# Item index: 11327
# Length of prefixes: 14500
# caption2embedding: 13006
# Item index: 13006
# Length of prefixes: 14500
# caption2embedding: 4185
# Item index: 4185
# coco_prefix:  93% 841/906 [08:01<00:37,  1.75it/s, loss=2.4]Length of prefixes: 14500
# caption2embedding: 11385
# Item index: 11385
# Length of prefixes: 14500
# caption2embedding: 14102
# Item index: 14102
# Length of prefixes: 14500
# caption2embedding: 3973
# Item index: 3973
# Length of prefixes: 14500
# caption2embedding: 10382
# Item index: 10382
# Length of prefixes: 14500
# caption2embedding: 13710
# Item index: 13710
# Length of prefixes: 14500
# caption2embedding: 10250
# Item index: 10250
# Length of prefixes: 14500
# caption2embedding: 11277
# Item index: 11277
# Length of prefixes: 14500
# caption2embedding: 165
# Item index: 165
# Length of prefixes: 14500
# caption2embedding: 5213
# Item index: 5213
# Length of prefixes: 14500
# caption2embedding: 7603
# Item index: 7603
# Length of prefixes: 14500
# caption2embedding: 10396
# Item index: 10396
# Length of prefixes: 14500
# caption2embedding: 11421
# Item index: 11421
# Length of prefixes: 14500
# caption2embedding: 1113
# Item index: 1113
# Length of prefixes: 14500
# caption2embedding: 2097
# Item index: 2097
# Length of prefixes: 14500
# caption2embedding: 9038
# Item index: 9038
# Length of prefixes: 14500
# caption2embedding: 11384
# Item index: 11384
# coco_prefix:  93% 842/906 [08:02<00:36,  1.76it/s, loss=2.23]Length of prefixes: 14500
# caption2embedding: 7240
# Item index: 7240
# Length of prefixes: 14500
# caption2embedding: 5913
# Item index: 5913
# Length of prefixes: 14500
# caption2embedding: 14134
# Item index: 14134
# Length of prefixes: 14500
# caption2embedding: 12253
# Item index: 12253
# Length of prefixes: 14500
# caption2embedding: 8253
# Item index: 8253
# Length of prefixes: 14500
# caption2embedding: 12365
# Item index: 12365
# Length of prefixes: 14500
# caption2embedding: 5551
# Item index: 5551
# Length of prefixes: 14500
# caption2embedding: 5597
# Item index: 5597
# Length of prefixes: 14500
# caption2embedding: 12340
# Item index: 12340
# Length of prefixes: 14500
# caption2embedding: 964
# Item index: 964
# Length of prefixes: 14500
# caption2embedding: 9277
# Item index: 9277
# Length of prefixes: 14500
# caption2embedding: 5649
# Item index: 5649
# Length of prefixes: 14500
# caption2embedding: 11334
# Item index: 11334
# Length of prefixes: 14500
# caption2embedding: 9519
# Item index: 9519
# Length of prefixes: 14500
# caption2embedding: 8557
# Item index: 8557
# Length of prefixes: 14500
# caption2embedding: 497
# Item index: 497
# coco_prefix:  93% 843/906 [08:02<00:35,  1.76it/s, loss=2.56]Length of prefixes: 14500
# caption2embedding: 2259
# Item index: 2259
# Length of prefixes: 14500
# caption2embedding: 1220
# Item index: 1220
# Length of prefixes: 14500
# caption2embedding: 1326
# Item index: 1326
# Length of prefixes: 14500
# caption2embedding: 11007
# Item index: 11007
# Length of prefixes: 14500
# caption2embedding: 5625
# Item index: 5625
# Length of prefixes: 14500
# caption2embedding: 600
# Item index: 600
# Length of prefixes: 14500
# caption2embedding: 10929
# Item index: 10929
# Length of prefixes: 14500
# caption2embedding: 9051
# Item index: 9051
# Length of prefixes: 14500
# caption2embedding: 11587
# Item index: 11587
# Length of prefixes: 14500
# caption2embedding: 611
# Item index: 611
# Length of prefixes: 14500
# caption2embedding: 9961
# Item index: 9961
# Length of prefixes: 14500
# caption2embedding: 2182
# Item index: 2182
# Length of prefixes: 14500
# caption2embedding: 1752
# Item index: 1752
# Length of prefixes: 14500
# caption2embedding: 7568
# Item index: 7568
# Length of prefixes: 14500
# caption2embedding: 2553
# Item index: 2553
# Length of prefixes: 14500
# caption2embedding: 7366
# Item index: 7366
# coco_prefix:  93% 844/906 [08:03<00:35,  1.75it/s, loss=2.58]Length of prefixes: 14500
# caption2embedding: 14125
# Item index: 14125
# Length of prefixes: 14500
# caption2embedding: 5179
# Item index: 5179
# Length of prefixes: 14500
# caption2embedding: 11664
# Item index: 11664
# Length of prefixes: 14500
# caption2embedding: 3515
# Item index: 3515
# Length of prefixes: 14500
# caption2embedding: 4107
# Item index: 4107
# Length of prefixes: 14500
# caption2embedding: 12611
# Item index: 12611
# Length of prefixes: 14500
# caption2embedding: 2069
# Item index: 2069
# Length of prefixes: 14500
# caption2embedding: 5505
# Item index: 5505
# Length of prefixes: 14500
# caption2embedding: 2393
# Item index: 2393
# Length of prefixes: 14500
# caption2embedding: 3142
# Item index: 3142
# Length of prefixes: 14500
# caption2embedding: 2078
# Item index: 2078
# Length of prefixes: 14500
# caption2embedding: 3394
# Item index: 3394
# Length of prefixes: 14500
# caption2embedding: 8702
# Item index: 8702
# Length of prefixes: 14500
# caption2embedding: 3853
# Item index: 3853
# Length of prefixes: 14500
# caption2embedding: 8534
# Item index: 8534
# Length of prefixes: 14500
# caption2embedding: 357
# Item index: 357
# coco_prefix:  93% 845/906 [08:04<00:34,  1.75it/s, loss=2.37]Length of prefixes: 14500
# caption2embedding: 1966
# Item index: 1966
# Length of prefixes: 14500
# caption2embedding: 7593
# Item index: 7593
# Length of prefixes: 14500
# caption2embedding: 4378
# Item index: 4378
# Length of prefixes: 14500
# caption2embedding: 11410
# Item index: 11410
# Length of prefixes: 14500
# caption2embedding: 3060
# Item index: 3060
# Length of prefixes: 14500
# caption2embedding: 5412
# Item index: 5412
# Length of prefixes: 14500
# caption2embedding: 8188
# Item index: 8188
# Length of prefixes: 14500
# caption2embedding: 12277
# Item index: 12277
# Length of prefixes: 14500
# caption2embedding: 10030
# Item index: 10030
# Length of prefixes: 14500
# caption2embedding: 10081
# Item index: 10081
# Length of prefixes: 14500
# caption2embedding: 5314
# Item index: 5314
# Length of prefixes: 14500
# caption2embedding: 1958
# Item index: 1958
# Length of prefixes: 14500
# caption2embedding: 2237
# Item index: 2237
# Length of prefixes: 14500
# caption2embedding: 13599
# Item index: 13599
# Length of prefixes: 14500
# caption2embedding: 6246
# Item index: 6246
# Length of prefixes: 14500
# caption2embedding: 5714
# Item index: 5714
# coco_prefix:  93% 846/906 [08:04<00:34,  1.75it/s, loss=2.43]Length of prefixes: 14500
# caption2embedding: 705
# Item index: 705
# Length of prefixes: 14500
# caption2embedding: 8803
# Item index: 8803
# Length of prefixes: 14500
# caption2embedding: 877
# Item index: 877
# Length of prefixes: 14500
# caption2embedding: 758
# Item index: 758
# Length of prefixes: 14500
# caption2embedding: 10863
# Item index: 10863
# Length of prefixes: 14500
# caption2embedding: 5120
# Item index: 5120
# Length of prefixes: 14500
# caption2embedding: 12472
# Item index: 12472
# Length of prefixes: 14500
# caption2embedding: 12256
# Item index: 12256
# Length of prefixes: 14500
# caption2embedding: 6183
# Item index: 6183
# Length of prefixes: 14500
# caption2embedding: 5894
# Item index: 5894
# Length of prefixes: 14500
# caption2embedding: 1509
# Item index: 1509
# Length of prefixes: 14500
# caption2embedding: 2358
# Item index: 2358
# Length of prefixes: 14500
# caption2embedding: 13999
# Item index: 13999
# Length of prefixes: 14500
# caption2embedding: 6566
# Item index: 6566
# Length of prefixes: 14500
# caption2embedding: 12857
# Item index: 12857
# Length of prefixes: 14500
# caption2embedding: 12236
# Item index: 12236
# coco_prefix:  93% 847/906 [08:05<00:33,  1.75it/s, loss=2.4]Length of prefixes: 14500
# caption2embedding: 10346
# Item index: 10346
# Length of prefixes: 14500
# caption2embedding: 640
# Item index: 640
# Length of prefixes: 14500
# caption2embedding: 10614
# Item index: 10614
# Length of prefixes: 14500
# caption2embedding: 6837
# Item index: 6837
# Length of prefixes: 14500
# caption2embedding: 3403
# Item index: 3403
# Length of prefixes: 14500
# caption2embedding: 14055
# Item index: 14055
# Length of prefixes: 14500
# caption2embedding: 8145
# Item index: 8145
# Length of prefixes: 14500
# caption2embedding: 13661
# Item index: 13661
# Length of prefixes: 14500
# caption2embedding: 7977
# Item index: 7977
# Length of prefixes: 14500
# caption2embedding: 12569
# Item index: 12569
# Length of prefixes: 14500
# caption2embedding: 12761
# Item index: 12761
# Length of prefixes: 14500
# caption2embedding: 11614
# Item index: 11614
# Length of prefixes: 14500
# caption2embedding: 6574
# Item index: 6574
# Length of prefixes: 14500
# caption2embedding: 917
# Item index: 917
# Length of prefixes: 14500
# caption2embedding: 13154
# Item index: 13154
# Length of prefixes: 14500
# caption2embedding: 10592
# Item index: 10592
# coco_prefix:  94% 848/906 [08:05<00:33,  1.75it/s, loss=2.5]Length of prefixes: 14500
# caption2embedding: 6127
# Item index: 6127
# Length of prefixes: 14500
# caption2embedding: 5205
# Item index: 5205
# Length of prefixes: 14500
# caption2embedding: 13365
# Item index: 13365
# Length of prefixes: 14500
# caption2embedding: 11560
# Item index: 11560
# Length of prefixes: 14500
# caption2embedding: 1040
# Item index: 1040
# Length of prefixes: 14500
# caption2embedding: 14418
# Item index: 14418
# Length of prefixes: 14500
# caption2embedding: 1413
# Item index: 1413
# Length of prefixes: 14500
# caption2embedding: 9474
# Item index: 9474
# Length of prefixes: 14500
# caption2embedding: 10896
# Item index: 10896
# Length of prefixes: 14500
# caption2embedding: 252
# Item index: 252
# Length of prefixes: 14500
# caption2embedding: 12784
# Item index: 12784
# Length of prefixes: 14500
# caption2embedding: 4377
# Item index: 4377
# Length of prefixes: 14500
# caption2embedding: 10567
# Item index: 10567
# Length of prefixes: 14500
# caption2embedding: 1128
# Item index: 1128
# Length of prefixes: 14500
# caption2embedding: 14287
# Item index: 14287
# Length of prefixes: 14500
# caption2embedding: 1058
# Item index: 1058
# coco_prefix:  94% 849/906 [08:06<00:32,  1.75it/s, loss=2.16]Length of prefixes: 14500
# caption2embedding: 11695
# Item index: 11695
# Length of prefixes: 14500
# caption2embedding: 1036
# Item index: 1036
# Length of prefixes: 14500
# caption2embedding: 2979
# Item index: 2979
# Length of prefixes: 14500
# caption2embedding: 7921
# Item index: 7921
# Length of prefixes: 14500
# caption2embedding: 7038
# Item index: 7038
# Length of prefixes: 14500
# caption2embedding: 12292
# Item index: 12292
# Length of prefixes: 14500
# caption2embedding: 7654
# Item index: 7654
# Length of prefixes: 14500
# caption2embedding: 2845
# Item index: 2845
# Length of prefixes: 14500
# caption2embedding: 10999
# Item index: 10999
# Length of prefixes: 14500
# caption2embedding: 2215
# Item index: 2215
# Length of prefixes: 14500
# caption2embedding: 4964
# Item index: 4964
# Length of prefixes: 14500
# caption2embedding: 6955
# Item index: 6955
# Length of prefixes: 14500
# caption2embedding: 6585
# Item index: 6585
# Length of prefixes: 14500
# caption2embedding: 10675
# Item index: 10675
# Length of prefixes: 14500
# caption2embedding: 8827
# Item index: 8827
# Length of prefixes: 14500
# caption2embedding: 11408
# Item index: 11408
# coco_prefix:  94% 850/906 [08:06<00:32,  1.75it/s, loss=2.47]Length of prefixes: 14500
# caption2embedding: 4134
# Item index: 4134
# Length of prefixes: 14500
# caption2embedding: 3200
# Item index: 3200
# Length of prefixes: 14500
# caption2embedding: 8021
# Item index: 8021
# Length of prefixes: 14500
# caption2embedding: 7623
# Item index: 7623
# Length of prefixes: 14500
# caption2embedding: 967
# Item index: 967
# Length of prefixes: 14500
# caption2embedding: 13822
# Item index: 13822
# Length of prefixes: 14500
# caption2embedding: 9863
# Item index: 9863
# Length of prefixes: 14500
# caption2embedding: 12272
# Item index: 12272
# Length of prefixes: 14500
# caption2embedding: 14084
# Item index: 14084
# Length of prefixes: 14500
# caption2embedding: 5082
# Item index: 5082
# Length of prefixes: 14500
# caption2embedding: 1921
# Item index: 1921
# Length of prefixes: 14500
# caption2embedding: 5521
# Item index: 5521
# Length of prefixes: 14500
# caption2embedding: 1330
# Item index: 1330
# Length of prefixes: 14500
# caption2embedding: 7003
# Item index: 7003
# Length of prefixes: 14500
# caption2embedding: 10128
# Item index: 10128
# Length of prefixes: 14500
# caption2embedding: 1709
# Item index: 1709
# coco_prefix:  94% 851/906 [08:07<00:31,  1.75it/s, loss=2.47]Length of prefixes: 14500
# caption2embedding: 7495
# Item index: 7495
# Length of prefixes: 14500
# caption2embedding: 1627
# Item index: 1627
# Length of prefixes: 14500
# caption2embedding: 1150
# Item index: 1150
# Length of prefixes: 14500
# caption2embedding: 12806
# Item index: 12806
# Length of prefixes: 14500
# caption2embedding: 4319
# Item index: 4319
# Length of prefixes: 14500
# caption2embedding: 10145
# Item index: 10145
# Length of prefixes: 14500
# caption2embedding: 9931
# Item index: 9931
# Length of prefixes: 14500
# caption2embedding: 2122
# Item index: 2122
# Length of prefixes: 14500
# caption2embedding: 10340
# Item index: 10340
# Length of prefixes: 14500
# caption2embedding: 2781
# Item index: 2781
# Length of prefixes: 14500
# caption2embedding: 6684
# Item index: 6684
# Length of prefixes: 14500
# caption2embedding: 6231
# Item index: 6231
# Length of prefixes: 14500
# caption2embedding: 12770
# Item index: 12770
# Length of prefixes: 14500
# caption2embedding: 9612
# Item index: 9612
# Length of prefixes: 14500
# caption2embedding: 7119
# Item index: 7119
# Length of prefixes: 14500
# caption2embedding: 7683
# Item index: 7683
# coco_prefix:  94% 852/906 [08:08<00:30,  1.75it/s, loss=2.23]Length of prefixes: 14500
# caption2embedding: 3218
# Item index: 3218
# Length of prefixes: 14500
# caption2embedding: 11214
# Item index: 11214
# Length of prefixes: 14500
# caption2embedding: 11771
# Item index: 11771
# Length of prefixes: 14500
# caption2embedding: 5820
# Item index: 5820
# Length of prefixes: 14500
# caption2embedding: 9099
# Item index: 9099
# Length of prefixes: 14500
# caption2embedding: 3132
# Item index: 3132
# Length of prefixes: 14500
# caption2embedding: 14163
# Item index: 14163
# Length of prefixes: 14500
# caption2embedding: 2856
# Item index: 2856
# Length of prefixes: 14500
# caption2embedding: 5997
# Item index: 5997
# Length of prefixes: 14500
# caption2embedding: 9027
# Item index: 9027
# Length of prefixes: 14500
# caption2embedding: 8247
# Item index: 8247
# Length of prefixes: 14500
# caption2embedding: 10776
# Item index: 10776
# Length of prefixes: 14500
# caption2embedding: 2620
# Item index: 2620
# Length of prefixes: 14500
# caption2embedding: 534
# Item index: 534
# Length of prefixes: 14500
# caption2embedding: 7636
# Item index: 7636
# Length of prefixes: 14500
# caption2embedding: 2447
# Item index: 2447
# coco_prefix:  94% 853/906 [08:08<00:30,  1.75it/s, loss=2.5]Length of prefixes: 14500
# caption2embedding: 4545
# Item index: 4545
# Length of prefixes: 14500
# caption2embedding: 3326
# Item index: 3326
# Length of prefixes: 14500
# caption2embedding: 6012
# Item index: 6012
# Length of prefixes: 14500
# caption2embedding: 5102
# Item index: 5102
# Length of prefixes: 14500
# caption2embedding: 4892
# Item index: 4892
# Length of prefixes: 14500
# caption2embedding: 8353
# Item index: 8353
# Length of prefixes: 14500
# caption2embedding: 8597
# Item index: 8597
# Length of prefixes: 14500
# caption2embedding: 11241
# Item index: 11241
# Length of prefixes: 14500
# caption2embedding: 12341
# Item index: 12341
# Length of prefixes: 14500
# caption2embedding: 9019
# Item index: 9019
# Length of prefixes: 14500
# caption2embedding: 14103
# Item index: 14103
# Length of prefixes: 14500
# caption2embedding: 11720
# Item index: 11720
# Length of prefixes: 14500
# caption2embedding: 6741
# Item index: 6741
# Length of prefixes: 14500
# caption2embedding: 7621
# Item index: 7621
# Length of prefixes: 14500
# caption2embedding: 3704
# Item index: 3704
# Length of prefixes: 14500
# caption2embedding: 3455
# Item index: 3455
# coco_prefix:  94% 854/906 [08:09<00:29,  1.75it/s, loss=2.57]Length of prefixes: 14500
# caption2embedding: 5999
# Item index: 5999
# Length of prefixes: 14500
# caption2embedding: 13632
# Item index: 13632
# Length of prefixes: 14500
# caption2embedding: 7477
# Item index: 7477
# Length of prefixes: 14500
# caption2embedding: 2108
# Item index: 2108
# Length of prefixes: 14500
# caption2embedding: 3621
# Item index: 3621
# Length of prefixes: 14500
# caption2embedding: 1711
# Item index: 1711
# Length of prefixes: 14500
# caption2embedding: 672
# Item index: 672
# Length of prefixes: 14500
# caption2embedding: 8384
# Item index: 8384
# Length of prefixes: 14500
# caption2embedding: 12039
# Item index: 12039
# Length of prefixes: 14500
# caption2embedding: 2583
# Item index: 2583
# Length of prefixes: 14500
# caption2embedding: 12765
# Item index: 12765
# Length of prefixes: 14500
# caption2embedding: 11432
# Item index: 11432
# Length of prefixes: 14500
# caption2embedding: 2076
# Item index: 2076
# Length of prefixes: 14500
# caption2embedding: 12029
# Item index: 12029
# Length of prefixes: 14500
# caption2embedding: 4908
# Item index: 4908
# Length of prefixes: 14500
# caption2embedding: 261
# Item index: 261
# coco_prefix:  94% 855/906 [08:09<00:29,  1.75it/s, loss=2.34]Length of prefixes: 14500
# caption2embedding: 531
# Item index: 531
# Length of prefixes: 14500
# caption2embedding: 12437
# Item index: 12437
# Length of prefixes: 14500
# caption2embedding: 225
# Item index: 225
# Length of prefixes: 14500
# caption2embedding: 3481
# Item index: 3481
# Length of prefixes: 14500
# caption2embedding: 13356
# Item index: 13356
# Length of prefixes: 14500
# caption2embedding: 11775
# Item index: 11775
# Length of prefixes: 14500
# caption2embedding: 2895
# Item index: 2895
# Length of prefixes: 14500
# caption2embedding: 11849
# Item index: 11849
# Length of prefixes: 14500
# caption2embedding: 2503
# Item index: 2503
# Length of prefixes: 14500
# caption2embedding: 13582
# Item index: 13582
# Length of prefixes: 14500
# caption2embedding: 11440
# Item index: 11440
# Length of prefixes: 14500
# caption2embedding: 8667
# Item index: 8667
# Length of prefixes: 14500
# caption2embedding: 36
# Item index: 36
# Length of prefixes: 14500
# caption2embedding: 35
# Item index: 35
# Length of prefixes: 14500
# caption2embedding: 11914
# Item index: 11914
# Length of prefixes: 14500
# caption2embedding: 2398
# Item index: 2398
# coco_prefix:  94% 856/906 [08:10<00:28,  1.75it/s, loss=2.35]Length of prefixes: 14500
# caption2embedding: 4189
# Item index: 4189
# Length of prefixes: 14500
# caption2embedding: 3509
# Item index: 3509
# Length of prefixes: 14500
# caption2embedding: 8842
# Item index: 8842
# Length of prefixes: 14500
# caption2embedding: 12724
# Item index: 12724
# Length of prefixes: 14500
# caption2embedding: 7859
# Item index: 7859
# Length of prefixes: 14500
# caption2embedding: 8546
# Item index: 8546
# Length of prefixes: 14500
# caption2embedding: 8066
# Item index: 8066
# Length of prefixes: 14500
# caption2embedding: 615
# Item index: 615
# Length of prefixes: 14500
# caption2embedding: 6253
# Item index: 6253
# Length of prefixes: 14500
# caption2embedding: 11437
# Item index: 11437
# Length of prefixes: 14500
# caption2embedding: 11260
# Item index: 11260
# Length of prefixes: 14500
# caption2embedding: 1812
# Item index: 1812
# Length of prefixes: 14500
# caption2embedding: 6853
# Item index: 6853
# Length of prefixes: 14500
# caption2embedding: 1686
# Item index: 1686
# Length of prefixes: 14500
# caption2embedding: 9110
# Item index: 9110
# Length of prefixes: 14500
# caption2embedding: 12076
# Item index: 12076
# coco_prefix:  95% 857/906 [08:10<00:27,  1.75it/s, loss=2.32]Length of prefixes: 14500
# caption2embedding: 14156
# Item index: 14156
# Length of prefixes: 14500
# caption2embedding: 5872
# Item index: 5872
# Length of prefixes: 14500
# caption2embedding: 2888
# Item index: 2888
# Length of prefixes: 14500
# caption2embedding: 10840
# Item index: 10840
# Length of prefixes: 14500
# caption2embedding: 8752
# Item index: 8752
# Length of prefixes: 14500
# caption2embedding: 11768
# Item index: 11768
# Length of prefixes: 14500
# caption2embedding: 11815
# Item index: 11815
# Length of prefixes: 14500
# caption2embedding: 272
# Item index: 272
# Length of prefixes: 14500
# caption2embedding: 4987
# Item index: 4987
# Length of prefixes: 14500
# caption2embedding: 810
# Item index: 810
# Length of prefixes: 14500
# caption2embedding: 7892
# Item index: 7892
# Length of prefixes: 14500
# caption2embedding: 7317
# Item index: 7317
# Length of prefixes: 14500
# caption2embedding: 7211
# Item index: 7211
# Length of prefixes: 14500
# caption2embedding: 10879
# Item index: 10879
# Length of prefixes: 14500
# caption2embedding: 13347
# Item index: 13347
# Length of prefixes: 14500
# caption2embedding: 6816
# Item index: 6816
# coco_prefix:  95% 858/906 [08:11<00:27,  1.75it/s, loss=2.38]Length of prefixes: 14500
# caption2embedding: 5513
# Item index: 5513
# Length of prefixes: 14500
# caption2embedding: 7819
# Item index: 7819
# Length of prefixes: 14500
# caption2embedding: 11064
# Item index: 11064
# Length of prefixes: 14500
# caption2embedding: 3483
# Item index: 3483
# Length of prefixes: 14500
# caption2embedding: 5141
# Item index: 5141
# Length of prefixes: 14500
# caption2embedding: 695
# Item index: 695
# Length of prefixes: 14500
# caption2embedding: 2826
# Item index: 2826
# Length of prefixes: 14500
# caption2embedding: 209
# Item index: 209
# Length of prefixes: 14500
# caption2embedding: 4127
# Item index: 4127
# Length of prefixes: 14500
# caption2embedding: 3355
# Item index: 3355
# Length of prefixes: 14500
# caption2embedding: 616
# Item index: 616
# Length of prefixes: 14500
# caption2embedding: 8195
# Item index: 8195
# Length of prefixes: 14500
# caption2embedding: 2757
# Item index: 2757
# Length of prefixes: 14500
# caption2embedding: 13433
# Item index: 13433
# Length of prefixes: 14500
# caption2embedding: 8700
# Item index: 8700
# Length of prefixes: 14500
# caption2embedding: 11005
# Item index: 11005
# coco_prefix:  95% 859/906 [08:12<00:26,  1.75it/s, loss=2.48]Length of prefixes: 14500
# caption2embedding: 327
# Item index: 327
# Length of prefixes: 14500
# caption2embedding: 1000
# Item index: 1000
# Length of prefixes: 14500
# caption2embedding: 12356
# Item index: 12356
# Length of prefixes: 14500
# caption2embedding: 9431
# Item index: 9431
# Length of prefixes: 14500
# caption2embedding: 3361
# Item index: 3361
# Length of prefixes: 14500
# caption2embedding: 3581
# Item index: 3581
# Length of prefixes: 14500
# caption2embedding: 11544
# Item index: 11544
# Length of prefixes: 14500
# caption2embedding: 9200
# Item index: 9200
# Length of prefixes: 14500
# caption2embedding: 5934
# Item index: 5934
# Length of prefixes: 14500
# caption2embedding: 11686
# Item index: 11686
# Length of prefixes: 14500
# caption2embedding: 6868
# Item index: 6868
# Length of prefixes: 14500
# caption2embedding: 7074
# Item index: 7074
# Length of prefixes: 14500
# caption2embedding: 11056
# Item index: 11056
# Length of prefixes: 14500
# caption2embedding: 4079
# Item index: 4079
# Length of prefixes: 14500
# caption2embedding: 7241
# Item index: 7241
# Length of prefixes: 14500
# caption2embedding: 399
# Item index: 399
# coco_prefix:  95% 860/906 [08:12<00:26,  1.75it/s, loss=2.42]Length of prefixes: 14500
# caption2embedding: 2377
# Item index: 2377
# Length of prefixes: 14500
# caption2embedding: 3794
# Item index: 3794
# Length of prefixes: 14500
# caption2embedding: 7197
# Item index: 7197
# Length of prefixes: 14500
# caption2embedding: 9799
# Item index: 9799
# Length of prefixes: 14500
# caption2embedding: 5845
# Item index: 5845
# Length of prefixes: 14500
# caption2embedding: 9515
# Item index: 9515
# Length of prefixes: 14500
# caption2embedding: 3237
# Item index: 3237
# Length of prefixes: 14500
# caption2embedding: 4235
# Item index: 4235
# Length of prefixes: 14500
# caption2embedding: 9867
# Item index: 9867
# Length of prefixes: 14500
# caption2embedding: 7679
# Item index: 7679
# Length of prefixes: 14500
# caption2embedding: 4511
# Item index: 4511
# Length of prefixes: 14500
# caption2embedding: 595
# Item index: 595
# Length of prefixes: 14500
# caption2embedding: 9581
# Item index: 9581
# Length of prefixes: 14500
# caption2embedding: 12304
# Item index: 12304
# Length of prefixes: 14500
# caption2embedding: 1777
# Item index: 1777
# Length of prefixes: 14500
# caption2embedding: 13489
# Item index: 13489
# coco_prefix:  95% 861/906 [08:13<00:25,  1.75it/s, loss=2.26]Length of prefixes: 14500
# caption2embedding: 6791
# Item index: 6791
# Length of prefixes: 14500
# caption2embedding: 12282
# Item index: 12282
# Length of prefixes: 14500
# caption2embedding: 1583
# Item index: 1583
# Length of prefixes: 14500
# caption2embedding: 378
# Item index: 378
# Length of prefixes: 14500
# caption2embedding: 11216
# Item index: 11216
# Length of prefixes: 14500
# caption2embedding: 1236
# Item index: 1236
# Length of prefixes: 14500
# caption2embedding: 175
# Item index: 175
# Length of prefixes: 14500
# caption2embedding: 3409
# Item index: 3409
# Length of prefixes: 14500
# caption2embedding: 12106
# Item index: 12106
# Length of prefixes: 14500
# caption2embedding: 12137
# Item index: 12137
# Length of prefixes: 14500
# caption2embedding: 6582
# Item index: 6582
# Length of prefixes: 14500
# caption2embedding: 7588
# Item index: 7588
# Length of prefixes: 14500
# caption2embedding: 11370
# Item index: 11370
# Length of prefixes: 14500
# caption2embedding: 9365
# Item index: 9365
# Length of prefixes: 14500
# caption2embedding: 5901
# Item index: 5901
# Length of prefixes: 14500
# caption2embedding: 13173
# Item index: 13173
# coco_prefix:  95% 862/906 [08:13<00:25,  1.75it/s, loss=2.25]Length of prefixes: 14500
# caption2embedding: 12081
# Item index: 12081
# Length of prefixes: 14500
# caption2embedding: 2777
# Item index: 2777
# Length of prefixes: 14500
# caption2embedding: 4329
# Item index: 4329
# Length of prefixes: 14500
# caption2embedding: 7043
# Item index: 7043
# Length of prefixes: 14500
# caption2embedding: 9844
# Item index: 9844
# Length of prefixes: 14500
# caption2embedding: 6571
# Item index: 6571
# Length of prefixes: 14500
# caption2embedding: 7741
# Item index: 7741
# Length of prefixes: 14500
# caption2embedding: 6075
# Item index: 6075
# Length of prefixes: 14500
# caption2embedding: 4142
# Item index: 4142
# Length of prefixes: 14500
# caption2embedding: 12718
# Item index: 12718
# Length of prefixes: 14500
# caption2embedding: 6103
# Item index: 6103
# Length of prefixes: 14500
# caption2embedding: 14083
# Item index: 14083
# Length of prefixes: 14500
# caption2embedding: 5110
# Item index: 5110
# Length of prefixes: 14500
# caption2embedding: 5886
# Item index: 5886
# Length of prefixes: 14500
# caption2embedding: 149
# Item index: 149
# Length of prefixes: 14500
# caption2embedding: 9683
# Item index: 9683
# coco_prefix:  95% 863/906 [08:14<00:24,  1.75it/s, loss=2.37]Length of prefixes: 14500
# caption2embedding: 9073
# Item index: 9073
# Length of prefixes: 14500
# caption2embedding: 8801
# Item index: 8801
# Length of prefixes: 14500
# caption2embedding: 13463
# Item index: 13463
# Length of prefixes: 14500
# caption2embedding: 4916
# Item index: 4916
# Length of prefixes: 14500
# caption2embedding: 12879
# Item index: 12879
# Length of prefixes: 14500
# caption2embedding: 11484
# Item index: 11484
# Length of prefixes: 14500
# caption2embedding: 4033
# Item index: 4033
# Length of prefixes: 14500
# caption2embedding: 4139
# Item index: 4139
# Length of prefixes: 14500
# caption2embedding: 3492
# Item index: 3492
# Length of prefixes: 14500
# caption2embedding: 1566
# Item index: 1566
# Length of prefixes: 14500
# caption2embedding: 10339
# Item index: 10339
# Length of prefixes: 14500
# caption2embedding: 567
# Item index: 567
# Length of prefixes: 14500
# caption2embedding: 7905
# Item index: 7905
# Length of prefixes: 14500
# caption2embedding: 5409
# Item index: 5409
# Length of prefixes: 14500
# caption2embedding: 400
# Item index: 400
# Length of prefixes: 14500
# caption2embedding: 5436
# Item index: 5436
# coco_prefix:  95% 864/906 [08:14<00:23,  1.75it/s, loss=2.37]Length of prefixes: 14500
# caption2embedding: 628
# Item index: 628
# Length of prefixes: 14500
# caption2embedding: 7759
# Item index: 7759
# Length of prefixes: 14500
# caption2embedding: 3594
# Item index: 3594
# Length of prefixes: 14500
# caption2embedding: 5724
# Item index: 5724
# Length of prefixes: 14500
# caption2embedding: 349
# Item index: 349
# Length of prefixes: 14500
# caption2embedding: 10497
# Item index: 10497
# Length of prefixes: 14500
# caption2embedding: 11323
# Item index: 11323
# Length of prefixes: 14500
# caption2embedding: 5489
# Item index: 5489
# Length of prefixes: 14500
# caption2embedding: 13210
# Item index: 13210
# Length of prefixes: 14500
# caption2embedding: 2911
# Item index: 2911
# Length of prefixes: 14500
# caption2embedding: 1512
# Item index: 1512
# Length of prefixes: 14500
# caption2embedding: 11688
# Item index: 11688
# Length of prefixes: 14500
# caption2embedding: 3248
# Item index: 3248
# Length of prefixes: 14500
# caption2embedding: 9176
# Item index: 9176
# Length of prefixes: 14500
# caption2embedding: 9033
# Item index: 9033
# Length of prefixes: 14500
# caption2embedding: 4470
# Item index: 4470
# coco_prefix:  95% 865/906 [08:15<00:23,  1.75it/s, loss=2.55]Length of prefixes: 14500
# caption2embedding: 2146
# Item index: 2146
# Length of prefixes: 14500
# caption2embedding: 1563
# Item index: 1563
# Length of prefixes: 14500
# caption2embedding: 12994
# Item index: 12994
# Length of prefixes: 14500
# caption2embedding: 337
# Item index: 337
# Length of prefixes: 14500
# caption2embedding: 13988
# Item index: 13988
# Length of prefixes: 14500
# caption2embedding: 13937
# Item index: 13937
# Length of prefixes: 14500
# caption2embedding: 1072
# Item index: 1072
# Length of prefixes: 14500
# caption2embedding: 7536
# Item index: 7536
# Length of prefixes: 14500
# caption2embedding: 13933
# Item index: 13933
# Length of prefixes: 14500
# caption2embedding: 6498
# Item index: 6498
# Length of prefixes: 14500
# caption2embedding: 6226
# Item index: 6226
# Length of prefixes: 14500
# caption2embedding: 5340
# Item index: 5340
# Length of prefixes: 14500
# caption2embedding: 8074
# Item index: 8074
# Length of prefixes: 14500
# caption2embedding: 12482
# Item index: 12482
# Length of prefixes: 14500
# caption2embedding: 990
# Item index: 990
# Length of prefixes: 14500
# caption2embedding: 1414
# Item index: 1414
# coco_prefix:  96% 866/906 [08:16<00:22,  1.75it/s, loss=2.48]Length of prefixes: 14500
# caption2embedding: 5222
# Item index: 5222
# Length of prefixes: 14500
# caption2embedding: 6355
# Item index: 6355
# Length of prefixes: 14500
# caption2embedding: 11031
# Item index: 11031
# Length of prefixes: 14500
# caption2embedding: 5138
# Item index: 5138
# Length of prefixes: 14500
# caption2embedding: 11931
# Item index: 11931
# Length of prefixes: 14500
# caption2embedding: 7045
# Item index: 7045
# Length of prefixes: 14500
# caption2embedding: 81
# Item index: 81
# Length of prefixes: 14500
# caption2embedding: 10508
# Item index: 10508
# Length of prefixes: 14500
# caption2embedding: 11276
# Item index: 11276
# Length of prefixes: 14500
# caption2embedding: 12180
# Item index: 12180
# Length of prefixes: 14500
# caption2embedding: 10903
# Item index: 10903
# Length of prefixes: 14500
# caption2embedding: 1500
# Item index: 1500
# Length of prefixes: 14500
# caption2embedding: 8243
# Item index: 8243
# Length of prefixes: 14500
# caption2embedding: 4758
# Item index: 4758
# Length of prefixes: 14500
# caption2embedding: 11733
# Item index: 11733
# Length of prefixes: 14500
# caption2embedding: 5524
# Item index: 5524
# coco_prefix:  96% 867/906 [08:16<00:22,  1.75it/s, loss=2.42]Length of prefixes: 14500
# caption2embedding: 10705
# Item index: 10705
# Length of prefixes: 14500
# caption2embedding: 6344
# Item index: 6344
# Length of prefixes: 14500
# caption2embedding: 8112
# Item index: 8112
# Length of prefixes: 14500
# caption2embedding: 5949
# Item index: 5949
# Length of prefixes: 14500
# caption2embedding: 11143
# Item index: 11143
# Length of prefixes: 14500
# caption2embedding: 6975
# Item index: 6975
# Length of prefixes: 14500
# caption2embedding: 2586
# Item index: 2586
# Length of prefixes: 14500
# caption2embedding: 13381
# Item index: 13381
# Length of prefixes: 14500
# caption2embedding: 2192
# Item index: 2192
# Length of prefixes: 14500
# caption2embedding: 5271
# Item index: 5271
# Length of prefixes: 14500
# caption2embedding: 8560
# Item index: 8560
# Length of prefixes: 14500
# caption2embedding: 8773
# Item index: 8773
# Length of prefixes: 14500
# caption2embedding: 940
# Item index: 940
# Length of prefixes: 14500
# caption2embedding: 8141
# Item index: 8141
# Length of prefixes: 14500
# caption2embedding: 5103
# Item index: 5103
# Length of prefixes: 14500
# caption2embedding: 3324
# Item index: 3324
# coco_prefix:  96% 868/906 [08:17<00:21,  1.75it/s, loss=2.36]Length of prefixes: 14500
# caption2embedding: 665
# Item index: 665
# Length of prefixes: 14500
# caption2embedding: 4547
# Item index: 4547
# Length of prefixes: 14500
# caption2embedding: 12603
# Item index: 12603
# Length of prefixes: 14500
# caption2embedding: 13361
# Item index: 13361
# Length of prefixes: 14500
# caption2embedding: 3694
# Item index: 3694
# Length of prefixes: 14500
# caption2embedding: 4193
# Item index: 4193
# Length of prefixes: 14500
# caption2embedding: 1134
# Item index: 1134
# Length of prefixes: 14500
# caption2embedding: 7341
# Item index: 7341
# Length of prefixes: 14500
# caption2embedding: 11196
# Item index: 11196
# Length of prefixes: 14500
# caption2embedding: 1408
# Item index: 1408
# Length of prefixes: 14500
# caption2embedding: 6379
# Item index: 6379
# Length of prefixes: 14500
# caption2embedding: 10952
# Item index: 10952
# Length of prefixes: 14500
# caption2embedding: 9680
# Item index: 9680
# Length of prefixes: 14500
# caption2embedding: 11753
# Item index: 11753
# Length of prefixes: 14500
# caption2embedding: 4505
# Item index: 4505
# Length of prefixes: 14500
# caption2embedding: 588
# Item index: 588
# coco_prefix:  96% 869/906 [08:17<00:21,  1.75it/s, loss=2.37]Length of prefixes: 14500
# caption2embedding: 13647
# Item index: 13647
# Length of prefixes: 14500
# caption2embedding: 14285
# Item index: 14285
# Length of prefixes: 14500
# caption2embedding: 2785
# Item index: 2785
# Length of prefixes: 14500
# caption2embedding: 7925
# Item index: 7925
# Length of prefixes: 14500
# caption2embedding: 5905
# Item index: 5905
# Length of prefixes: 14500
# caption2embedding: 1477
# Item index: 1477
# Length of prefixes: 14500
# caption2embedding: 1918
# Item index: 1918
# Length of prefixes: 14500
# caption2embedding: 1537
# Item index: 1537
# Length of prefixes: 14500
# caption2embedding: 5180
# Item index: 5180
# Length of prefixes: 14500
# caption2embedding: 5062
# Item index: 5062
# Length of prefixes: 14500
# caption2embedding: 12537
# Item index: 12537
# Length of prefixes: 14500
# caption2embedding: 3365
# Item index: 3365
# Length of prefixes: 14500
# caption2embedding: 13545
# Item index: 13545
# Length of prefixes: 14500
# caption2embedding: 10738
# Item index: 10738
# Length of prefixes: 14500
# caption2embedding: 2659
# Item index: 2659
# Length of prefixes: 14500
# caption2embedding: 583
# Item index: 583
# coco_prefix:  96% 870/906 [08:18<00:20,  1.75it/s, loss=2.32]Length of prefixes: 14500
# caption2embedding: 3078
# Item index: 3078
# Length of prefixes: 14500
# caption2embedding: 2387
# Item index: 2387
# Length of prefixes: 14500
# caption2embedding: 13660
# Item index: 13660
# Length of prefixes: 14500
# caption2embedding: 7245
# Item index: 7245
# Length of prefixes: 14500
# caption2embedding: 8879
# Item index: 8879
# Length of prefixes: 14500
# caption2embedding: 9670
# Item index: 9670
# Length of prefixes: 14500
# caption2embedding: 3463
# Item index: 3463
# Length of prefixes: 14500
# caption2embedding: 9317
# Item index: 9317
# Length of prefixes: 14500
# caption2embedding: 9435
# Item index: 9435
# Length of prefixes: 14500
# caption2embedding: 7518
# Item index: 7518
# Length of prefixes: 14500
# caption2embedding: 952
# Item index: 952
# Length of prefixes: 14500
# caption2embedding: 2208
# Item index: 2208
# Length of prefixes: 14500
# caption2embedding: 7490
# Item index: 7490
# Length of prefixes: 14500
# caption2embedding: 607
# Item index: 607
# Length of prefixes: 14500
# caption2embedding: 5866
# Item index: 5866
# Length of prefixes: 14500
# caption2embedding: 10124
# Item index: 10124
# coco_prefix:  96% 871/906 [08:18<00:19,  1.76it/s, loss=2.52]Length of prefixes: 14500
# caption2embedding: 9238
# Item index: 9238
# Length of prefixes: 14500
# caption2embedding: 6351
# Item index: 6351
# Length of prefixes: 14500
# caption2embedding: 14146
# Item index: 14146
# Length of prefixes: 14500
# caption2embedding: 9000
# Item index: 9000
# Length of prefixes: 14500
# caption2embedding: 10283
# Item index: 10283
# Length of prefixes: 14500
# caption2embedding: 8704
# Item index: 8704
# Length of prefixes: 14500
# caption2embedding: 1605
# Item index: 1605
# Length of prefixes: 14500
# caption2embedding: 9443
# Item index: 9443
# Length of prefixes: 14500
# caption2embedding: 4845
# Item index: 4845
# Length of prefixes: 14500
# caption2embedding: 3349
# Item index: 3349
# Length of prefixes: 14500
# caption2embedding: 10269
# Item index: 10269
# Length of prefixes: 14500
# caption2embedding: 4696
# Item index: 4696
# Length of prefixes: 14500
# caption2embedding: 8902
# Item index: 8902
# Length of prefixes: 14500
# caption2embedding: 8067
# Item index: 8067
# Length of prefixes: 14500
# caption2embedding: 2614
# Item index: 2614
# Length of prefixes: 14500
# caption2embedding: 7966
# Item index: 7966
# coco_prefix:  96% 872/906 [08:19<00:19,  1.75it/s, loss=2.3]Length of prefixes: 14500
# caption2embedding: 4842
# Item index: 4842
# Length of prefixes: 14500
# caption2embedding: 3187
# Item index: 3187
# Length of prefixes: 14500
# caption2embedding: 9843
# Item index: 9843
# Length of prefixes: 14500
# caption2embedding: 3669
# Item index: 3669
# Length of prefixes: 14500
# caption2embedding: 6262
# Item index: 6262
# Length of prefixes: 14500
# caption2embedding: 9142
# Item index: 9142
# Length of prefixes: 14500
# caption2embedding: 9571
# Item index: 9571
# Length of prefixes: 14500
# caption2embedding: 53
# Item index: 53
# Length of prefixes: 14500
# caption2embedding: 8351
# Item index: 8351
# Length of prefixes: 14500
# caption2embedding: 10669
# Item index: 10669
# Length of prefixes: 14500
# caption2embedding: 4797
# Item index: 4797
# Length of prefixes: 14500
# caption2embedding: 7563
# Item index: 7563
# Length of prefixes: 14500
# caption2embedding: 9942
# Item index: 9942
# Length of prefixes: 14500
# caption2embedding: 10224
# Item index: 10224
# Length of prefixes: 14500
# caption2embedding: 9854
# Item index: 9854
# Length of prefixes: 14500
# caption2embedding: 9676
# Item index: 9676
# coco_prefix:  96% 873/906 [08:20<00:18,  1.75it/s, loss=2.31]Length of prefixes: 14500
# caption2embedding: 4497
# Item index: 4497
# Length of prefixes: 14500
# caption2embedding: 14456
# Item index: 14456
# Length of prefixes: 14500
# caption2embedding: 3680
# Item index: 3680
# Length of prefixes: 14500
# caption2embedding: 11351
# Item index: 11351
# Length of prefixes: 14500
# caption2embedding: 7626
# Item index: 7626
# Length of prefixes: 14500
# caption2embedding: 11504
# Item index: 11504
# Length of prefixes: 14500
# caption2embedding: 13509
# Item index: 13509
# Length of prefixes: 14500
# caption2embedding: 4277
# Item index: 4277
# Length of prefixes: 14500
# caption2embedding: 8982
# Item index: 8982
# Length of prefixes: 14500
# caption2embedding: 7811
# Item index: 7811
# Length of prefixes: 14500
# caption2embedding: 1395
# Item index: 1395
# Length of prefixes: 14500
# caption2embedding: 2656
# Item index: 2656
# Length of prefixes: 14500
# caption2embedding: 8627
# Item index: 8627
# Length of prefixes: 14500
# caption2embedding: 9837
# Item index: 9837
# Length of prefixes: 14500
# caption2embedding: 869
# Item index: 869
# Length of prefixes: 14500
# caption2embedding: 2678
# Item index: 2678
# coco_prefix:  96% 874/906 [08:20<00:18,  1.75it/s, loss=2.43]Length of prefixes: 14500
# caption2embedding: 8379
# Item index: 8379
# Length of prefixes: 14500
# caption2embedding: 9215
# Item index: 9215
# Length of prefixes: 14500
# caption2embedding: 9098
# Item index: 9098
# Length of prefixes: 14500
# caption2embedding: 11510
# Item index: 11510
# Length of prefixes: 14500
# caption2embedding: 491
# Item index: 491
# Length of prefixes: 14500
# caption2embedding: 11747
# Item index: 11747
# Length of prefixes: 14500
# caption2embedding: 11772
# Item index: 11772
# Length of prefixes: 14500
# caption2embedding: 2773
# Item index: 2773
# Length of prefixes: 14500
# caption2embedding: 5727
# Item index: 5727
# Length of prefixes: 14500
# caption2embedding: 13700
# Item index: 13700
# Length of prefixes: 14500
# caption2embedding: 9072
# Item index: 9072
# Length of prefixes: 14500
# caption2embedding: 1960
# Item index: 1960
# Length of prefixes: 14500
# caption2embedding: 457
# Item index: 457
# Length of prefixes: 14500
# caption2embedding: 12871
# Item index: 12871
# Length of prefixes: 14500
# caption2embedding: 8796
# Item index: 8796
# Length of prefixes: 14500
# caption2embedding: 3882
# Item index: 3882
# coco_prefix:  97% 875/906 [08:21<00:17,  1.75it/s, loss=2.56]Length of prefixes: 14500
# caption2embedding: 5482
# Item index: 5482
# Length of prefixes: 14500
# caption2embedding: 10034
# Item index: 10034
# Length of prefixes: 14500
# caption2embedding: 11155
# Item index: 11155
# ...
# Item index: 174
# Length of prefixes: 505
# caption2embedding: 17
# Item index: 17
# Length of prefixes: 505
# caption2embedding: 328
# Item index: 328
# Length of prefixes: 505
# caption2embedding: 404
# Item index: 404
# Length of prefixes: 505
# caption2embedding: 235
# Item index: 235
# Length of prefixes: 505
# caption2embedding: 427
# Item index: 427
# Length of prefixes: 505
# caption2embedding: 487
# Item index: 487
# Length of prefixes: 505
# caption2embedding: 327
# Item index: 327
# Length of prefixes: 505
# caption2embedding: 120
# Item index: 120
# Length of prefixes: 505
# caption2embedding: 349
# Item index: 349
# Length of prefixes: 505
# caption2embedding: 449
# Item index: 449
# Length of prefixes: 505
# caption2embedding: 497
# Item index: 497
# Length of prefixes: 505
# caption2embedding: 288
# Item index: 288
# Length of prefixes: 505
# caption2embedding: 350
# Item index: 350
# Length of prefixes: 505
# caption2embedding: 91
# Item index: 91
# Length of prefixes: 505
# caption2embedding: 337
# Item index: 337
# Length of prefixes: 505
# caption2embedding: 49
# Item index: 49
# Length of prefixes: 505
# caption2embedding: 121
# Item index: 121
# Length of prefixes: 505
# caption2embedding: 307
# Item index: 307
# Length of prefixes: 505
# caption2embedding: 431
# Item index: 431
# Length of prefixes: 505
# caption2embedding: 412
# Item index: 412
# Length of prefixes: 505
# caption2embedding: 377
# Item index: 377
# Length of prefixes: 505
# caption2embedding: 138
# Item index: 138
# Length of prefixes: 505
# caption2embedding: 432
# Item index: 432
# Length of prefixes: 505
# caption2embedding: 29
# Item index: 29
# Length of prefixes: 505
# caption2embedding: 468
# Item index: 468
# Length of prefixes: 505
# caption2embedding: 204
# Item index: 204
# Length of prefixes: 505
# caption2embedding: 407
# Item index: 407
# Length of prefixes: 505
# caption2embedding: 192
# Item index: 192
# Length of prefixes: 505
# caption2embedding: 254
# Item index: 254
# Length of prefixes: 505
# caption2embedding: 188
# Item index: 188
# Length of prefixes: 505
# caption2embedding: 388
# Item index: 388
# Length of prefixes: 505
# caption2embedding: 227
# Item index: 227
# Length of prefixes: 505
# caption2embedding: 4
# Item index: 4
# Length of prefixes: 505
# caption2embedding: 298
# Item index: 298
# Length of prefixes: 505
# caption2embedding: 93
# Item index: 93
# Length of prefixes: 505
# caption2embedding: 486
# Item index: 486
# Length of prefixes: 505
# caption2embedding: 238
# Item index: 238
# Length of prefixes: 505
# caption2embedding: 162
# Item index: 162
# Length of prefixes: 505
# caption2embedding: 180
# Item index: 180
# Length of prefixes: 505
# caption2embedding: 316
# Item index: 316
# Length of prefixes: 505
# caption2embedding: 80
# Item index: 80
# Length of prefixes: 505
# caption2embedding: 448
# Item index: 448
# Length of prefixes: 505
# caption2embedding: 416
# Item index: 416
# Length of prefixes: 505
# caption2embedding: 488
# Item index: 488
# Length of prefixes: 505
# caption2embedding: 467
# Item index: 467
# Length of prefixes: 505
# caption2embedding: 131
# Item index: 131
# Length of prefixes: 505
# caption2embedding: 261
# Item index: 261
# Length of prefixes: 505
# caption2embedding: 301
# Item index: 301
# Length of prefixes: 505
# caption2embedding: 130
# Item index: 130
# Length of prefixes: 505
# caption2embedding: 503
# Item index: 503
# Length of prefixes: 505
# caption2embedding: 155
# Item index: 155
# Length of prefixes: 505
# caption2embedding: 63
# Item index: 63
# Length of prefixes: 505
# caption2embedding: 116
# Item index: 116
# Length of prefixes: 505
# caption2embedding: 128
# Item index: 128
# Length of prefixes: 505
# caption2embedding: 18
# Item index: 18
# Length of prefixes: 505
# caption2embedding: 27
# Item index: 27
# Length of prefixes: 505
# caption2embedding: 46
# Item index: 46
# Length of prefixes: 505
# caption2embedding: 137
# Item index: 137
# Length of prefixes: 505
# caption2embedding: 53
# Item index: 53
# Length of prefixes: 505
# caption2embedding: 344
# Item index: 344
# Length of prefixes: 505
# caption2embedding: 387
# Item index: 387
# Length of prefixes: 505
# caption2embedding: 106
# Item index: 106
# Length of prefixes: 505
# caption2embedding: 289
# Item index: 289
# Length of prefixes: 505
# caption2embedding: 171
# Item index: 171
# Length of prefixes: 505
# caption2embedding: 418
# Item index: 418
# Length of prefixes: 505
# caption2embedding: 347
# Item index: 347
# Length of prefixes: 505
# caption2embedding: 37
# Item index: 37
# Length of prefixes: 505
# caption2embedding: 321
# Item index: 321
# Length of prefixes: 505
# caption2embedding: 291
# Item index: 291
# Length of prefixes: 505
# caption2embedding: 243
# Item index: 243
# Length of prefixes: 505
# caption2embedding: 280
# Item index: 280
# Length of prefixes: 505
# caption2embedding: 186
# Item index: 186
# Length of prefixes: 505
# caption2embedding: 370
# Item index: 370
# Length of prefixes: 505
# caption2embedding: 385
# Item index: 385
# Length of prefixes: 505
# caption2embedding: 263
# Item index: 263
# Length of prefixes: 505
# caption2embedding: 45
# Item index: 45
# Length of prefixes: 505
# caption2embedding: 44
# Item index: 44
# Length of prefixes: 505
# caption2embedding: 206
# Item index: 206
# Length of prefixes: 505
# caption2embedding: 144
# Item index: 144
# Length of prefixes: 505
# caption2embedding: 446
# Item index: 446
# Length of prefixes: 505
# caption2embedding: 304
# Item index: 304
# Length of prefixes: 505
# caption2embedding: 267
# Item index: 267
# Length of prefixes: 505
# caption2embedding: 459
# Item index: 459
# Length of prefixes: 505
# caption2embedding: 64
# Item index: 64
# Length of prefixes: 505
# caption2embedding: 48
# Item index: 48
# Length of prefixes: 505
# caption2embedding: 358
# Item index: 358
# Length of prefixes: 505
# caption2embedding: 109
# Item index: 109
# Length of prefixes: 505
# caption2embedding: 152
# Item index: 152
# Length of prefixes: 505
# caption2embedding: 428
# Item index: 428
# Length of prefixes: 505
# caption2embedding: 413
# Item index: 413
# Length of prefixes: 505
# caption2embedding: 463
# Item index: 463
# Length of prefixes: 505
# caption2embedding: 366
# Item index: 366
# Length of prefixes: 505
# caption2embedding: 58
# Item index: 58
# Length of prefixes: 505
# caption2embedding: 99
# Item index: 99
# Length of prefixes: 505
# caption2embedding: 371
# Item index: 371
# Length of prefixes: 505
# caption2embedding: 209
# Item index: 209
# Length of prefixes: 505
# caption2embedding: 313
# Item index: 313
# Length of prefixes: 505
# caption2embedding: 83
# Item index: 83
# Length of prefixes: 505
# caption2embedding: 461
# Item index: 461
# Length of prefixes: 505
# caption2embedding: 439
# Item index: 439
# Length of prefixes: 505
# caption2embedding: 392
# Item index: 392
# Length of prefixes: 505
# caption2embedding: 443
# Item index: 443
# Length of prefixes: 505
# caption2embedding: 403
# Item index: 403
# Length of prefixes: 505
# caption2embedding: 426
# Item index: 426
# Length of prefixes: 505
# caption2embedding: 477
# Item index: 477
# Length of prefixes: 505
# caption2embedding: 228
# Item index: 228
# Length of prefixes: 505
# caption2embedding: 429
# Item index: 429
# Length of prefixes: 505
# caption2embedding: 223
# Item index: 223
# Length of prefixes: 505
# caption2embedding: 414
# Item index: 414
# Length of prefixes: 505
# caption2embedding: 164
# Item index: 164
# Length of prefixes: 505
# caption2embedding: 471
# Item index: 471
# Length of prefixes: 505
# caption2embedding: 406
# Item index: 406
# Length of prefixes: 505
# caption2embedding: 440
# Item index: 440
# Length of prefixes: 505
# caption2embedding: 335
# Item index: 335
# Length of prefixes: 505
# caption2embedding: 294
# Item index: 294
# Length of prefixes: 505
# caption2embedding: 495
# Item index: 495
# Length of prefixes: 505
# caption2embedding: 408
# Item index: 408
# Length of prefixes: 505
# caption2embedding: 103
# Item index: 103
# Length of prefixes: 505
# caption2embedding: 201
# Item index: 201
# Length of prefixes: 505
# caption2embedding: 207
# Item index: 207
# Length of prefixes: 505
# caption2embedding: 140
# Item index: 140
# Length of prefixes: 505
# caption2embedding: 118
# Item index: 118
# Length of prefixes: 505
# caption2embedding: 125
# Item index: 125
# Length of prefixes: 505
# caption2embedding: 233
# Item index: 233
# Length of prefixes: 505
# caption2embedding: 136
# Item index: 136
# Length of prefixes: 505
# caption2embedding: 453
# Item index: 453
# Length of prefixes: 505
# caption2embedding: 257
# Item index: 257
# Length of prefixes: 505
# caption2embedding: 410
# Item index: 410
# Length of prefixes: 505
# caption2embedding: 75
# Item index: 75
# Length of prefixes: 505
# caption2embedding: 6
# Item index: 6
# Length of prefixes: 505
# caption2embedding: 378
# Item index: 378
# Length of prefixes: 505
# caption2embedding: 102
# Item index: 102
# Length of prefixes: 505
# caption2embedding: 444
# Item index: 444
# Length of prefixes: 505
# caption2embedding: 178
# Item index: 178
# Length of prefixes: 505
# caption2embedding: 229
# Item index: 229
# Length of prefixes: 505
# caption2embedding: 305
# Item index: 305
# Length of prefixes: 505
# caption2embedding: 1
# Item index: 1
# Length of prefixes: 505
# caption2embedding: 41
# Item index: 41
# Length of prefixes: 505
# caption2embedding: 108
# Item index: 108
# Length of prefixes: 505
# caption2embedding: 383
# Item index: 383
# Length of prefixes: 505
# caption2embedding: 0
# Item index: 0
# Length of prefixes: 505
# caption2embedding: 156
# Item index: 156
# Length of prefixes: 505
# caption2embedding: 86
# Item index: 86
# Length of prefixes: 505
# caption2embedding: 160
# Item index: 160
# Length of prefixes: 505
# caption2embedding: 457
# Item index: 457
# Length of prefixes: 505
# caption2embedding: 319
# Item index: 319
# Length of prefixes: 505
# caption2embedding: 245
# Item index: 245
# Length of prefixes: 505
# caption2embedding: 275
# Item index: 275
# Length of prefixes: 505
# caption2embedding: 333
# Item index: 333
# Length of prefixes: 505
# caption2embedding: 409
# Item index: 409
# Length of prefixes: 505
# caption2embedding: 92
# Item index: 92
# Length of prefixes: 505
# caption2embedding: 322
# Item index: 322
# Length of prefixes: 505
# caption2embedding: 352
# Item index: 352
# Length of prefixes: 505
# caption2embedding: 266
# Item index: 266
# Length of prefixes: 505
# caption2embedding: 96
# Item index: 96
# Length of prefixes: 505
# caption2embedding: 203
# Item index: 203
# Length of prefixes: 505
# caption2embedding: 472
# Item index: 472
# Length of prefixes: 505
# caption2embedding: 127
# Item index: 127
# Length of prefixes: 505
# caption2embedding: 420
# Item index: 420
# Length of prefixes: 505
# caption2embedding: 187
# Item index: 187
# Length of prefixes: 505
# caption2embedding: 338
# Item index: 338
# Length of prefixes: 505
# caption2embedding: 159
# Item index: 159
# Length of prefixes: 505
# caption2embedding: 90
# Item index: 90
# Length of prefixes: 505
# caption2embedding: 374
# Item index: 374
# Length of prefixes: 505
# caption2embedding: 101
# Item index: 101
# Length of prefixes: 505
# caption2embedding: 47
# Item index: 47
# Length of prefixes: 505
# caption2embedding: 133
# Item index: 133
# Length of prefixes: 505
# caption2embedding: 82
# Item index: 82
# Length of prefixes: 505
# caption2embedding: 173
# Item index: 173
# Length of prefixes: 505
# caption2embedding: 438
# Item index: 438
# Length of prefixes: 505
# caption2embedding: 482
# Item index: 482
# Length of prefixes: 505
# caption2embedding: 60
# Item index: 60
# Length of prefixes: 505
# caption2embedding: 73
# Item index: 73
# Length of prefixes: 505
# caption2embedding: 360
# Item index: 360
# Length of prefixes: 505
# caption2embedding: 70
# Item index: 70
# Length of prefixes: 505
# caption2embedding: 107
# Item index: 107
# Length of prefixes: 505
# caption2embedding: 293
# Item index: 293
# Length of prefixes: 505
# caption2embedding: 470
# Item index: 470
# Length of prefixes: 505
# caption2embedding: 143
# Item index: 143
# Length of prefixes: 505
# caption2embedding: 119
# Item index: 119
# Length of prefixes: 505
# caption2embedding: 71
# Item index: 71
# Length of prefixes: 505
# caption2embedding: 423
# Item index: 423
# Length of prefixes: 505
# caption2embedding: 113
# Item index: 113
# Length of prefixes: 505
# caption2embedding: 216
# Item index: 216
# Length of prefixes: 505
# caption2embedding: 76
# Item index: 76
# Length of prefixes: 505
# caption2embedding: 382
# Item index: 382
# Length of prefixes: 505
# caption2embedding: 38
# Item index: 38
# Length of prefixes: 505
# caption2embedding: 424
# Item index: 424
# Length of prefixes: 505
# caption2embedding: 211
# Item index: 211
# Length of prefixes: 505
# caption2embedding: 452
# Item index: 452
# Length of prefixes: 505
# caption2embedding: 433
# Item index: 433
# Length of prefixes: 505
# caption2embedding: 447
# Item index: 447
# Length of prefixes: 505
# caption2embedding: 320
# Item index: 320
# Length of prefixes: 505
# caption2embedding: 5
# Item index: 5
# Length of prefixes: 505
# caption2embedding: 247
# Item index: 247
# Length of prefixes: 505
# caption2embedding: 25
# Item index: 25
# Length of prefixes: 505
# caption2embedding: 224
# Item index: 224
# Length of prefixes: 505
# caption2embedding: 362
# Item index: 362
# Length of prefixes: 505
# caption2embedding: 310
# Item index: 310
# Length of prefixes: 505
# caption2embedding: 455
# Item index: 455
# Length of prefixes: 505
# caption2embedding: 105
# Item index: 105
# Length of prefixes: 505
# caption2embedding: 175
# Item index: 175
# Length of prefixes: 505
# caption2embedding: 57
# Item index: 57
# Length of prefixes: 505
# caption2embedding: 430
# Item index: 430
# Length of prefixes: 505
# caption2embedding: 193
# Item index: 193
# Length of prefixes: 505
# caption2embedding: 483
# Item index: 483
# Length of prefixes: 505
# caption2embedding: 480
# Item index: 480
# Length of prefixes: 505
# caption2embedding: 353
# Item index: 353
# Length of prefixes: 505
# caption2embedding: 466
# Item index: 466
# Length of prefixes: 505
# caption2embedding: 332
# Item index: 332
# Length of prefixes: 505
# caption2embedding: 380
# Item index: 380
# Length of prefixes: 505
# caption2embedding: 436
# Item index: 436
# Length of prefixes: 505
# caption2embedding: 259
# Item index: 259
# Length of prefixes: 505
# caption2embedding: 42
# Item index: 42
# Length of prefixes: 505
# caption2embedding: 32
# Item index: 32
# Length of prefixes: 505
# caption2embedding: 330
# Item index: 330
# Length of prefixes: 505
# caption2embedding: 368
# Item index: 368
# Length of prefixes: 505
# caption2embedding: 311
# Item index: 311
# Length of prefixes: 505
# caption2embedding: 389
# Item index: 389
# Length of prefixes: 505
# caption2embedding: 494
# Item index: 494
# Length of prefixes: 505
# caption2embedding: 481
# Item index: 481
# Length of prefixes: 505
# caption2embedding: 69
# Item index: 69
# Length of prefixes: 505
# caption2embedding: 194
# Item index: 194
# Length of prefixes: 505
# caption2embedding: 236
# Item index: 236
# Length of prefixes: 505
# caption2embedding: 303
# Item index: 303
# Length of prefixes: 505
# caption2embedding: 252
# Item index: 252
# Length of prefixes: 505
# caption2embedding: 21
# Item index: 21
# Length of prefixes: 505
# caption2embedding: 39
# Item index: 39
# Length of prefixes: 505
# caption2embedding: 129
# Item index: 129
# Length of prefixes: 505
# caption2embedding: 340
# Item index: 340
# Length of prefixes: 505
# caption2embedding: 166
# Item index: 166
# Length of prefixes: 505
# caption2embedding: 242
# Item index: 242
# Length of prefixes: 505
# caption2embedding: 292
# Item index: 292
# Length of prefixes: 505
# caption2embedding: 376
# Item index: 376
# Length of prefixes: 505
# caption2embedding: 363
# Item index: 363
# Length of prefixes: 505
# caption2embedding: 199
# Item index: 199
# Length of prefixes: 505
# caption2embedding: 295
# Item index: 295
# Length of prefixes: 505
# caption2embedding: 77
# Item index: 77
# Length of prefixes: 505
# caption2embedding: 253
# Item index: 253
# Length of prefixes: 505
# caption2embedding: 23
# Item index: 23
# Length of prefixes: 505
# caption2embedding: 479
# Item index: 479
# Length of prefixes: 505
# caption2embedding: 359
# Item index: 359
# Length of prefixes: 505
# caption2embedding: 202
# Item index: 202
# Length of prefixes: 505
# caption2embedding: 50
# Item index: 50
# Length of prefixes: 505
# caption2embedding: 95
# Item index: 95
# Length of prefixes: 505
# caption2embedding: 354
# Item index: 354
# Length of prefixes: 505
# caption2embedding: 469
# Item index: 469
# Length of prefixes: 505
# caption2embedding: 198
# Item index: 198
# Length of prefixes: 505
# caption2embedding: 415
# Item index: 415
# Length of prefixes: 505
# caption2embedding: 265
# Item index: 265
# Length of prefixes: 505
# caption2embedding: 3
# Item index: 3
# Length of prefixes: 505
# caption2embedding: 240
# Item index: 240
# loss_per_epoch_val:  [3.1335441297100437, 3.008665184820852, 2.8577536536801245, 2.763614762213922, 2.704885390497023, 2.680600466266755, 2.660076102902812, 2.639070672373618, 2.637232642019949, 2.643124826492802]

# %%
# !python train.py --data FLICKR --out_dir "/content/trained_models/var_0.02_scratch/" --noise_variance 0.02 --bs 48 --prefix_length 50
# Out:
# Streaming output truncated to the last 5000 lines.
# Item index: 8126
# Length of prefixes: 14500
# caption2embedding: 8618
# Item index: 8618
# Length of prefixes: 14500
# caption2embedding: 10289
# Item index: 10289
# Length of prefixes: 14500
# caption2embedding: 162
# Item index: 162
# Length of prefixes: 14500
# caption2embedding: 6386
# Item index: 6386
# Length of prefixes: 14500
# caption2embedding: 11053
# Item index: 11053
# Length of prefixes: 14500
# caption2embedding: 10354
# Item index: 10354
# Length of prefixes: 14500
# caption2embedding: 941
# Item index: 941
# Length of prefixes: 14500
# caption2embedding: 9951
# Item index: 9951
# Length of prefixes: 14500
# caption2embedding: 7528
# Item index: 7528
# Length of prefixes: 14500
# caption2embedding: 4314
# Item index: 4314
# Length of prefixes: 14500
# caption2embedding: 12364
# Item index: 12364
# Length of prefixes: 14500
# caption2embedding: 11562
# Item index: 11562
# Length of prefixes: 14500
# caption2embedding: 5285
# Item index: 5285
# Length of prefixes: 14500
# caption2embedding: 8014
# Item index: 8014
# coco_prefix:  92% 834/906 [08:57<00:46,  1.55it/s, loss=2.42]Length of prefixes: 14500
# caption2embedding: 10433
# Item index: 10433
# Length of prefixes: 14500
# caption2embedding: 4133
# Item index: 4133
# Length of prefixes: 14500
# caption2embedding: 13995
# Item index: 13995
# Length of prefixes: 14500
# caption2embedding: 5660
# Item index: 5660
# Length of prefixes: 14500
# caption2embedding: 10229
# Item index: 10229
# Length of prefixes: 14500
# caption2embedding: 3093
# Item index: 3093
# Length of prefixes: 14500
# caption2embedding: 1869
# Item index: 1869
# Length of prefixes: 14500
# caption2embedding: 4619
# Item index: 4619
# Length of prefixes: 14500
# caption2embedding: 809
# Item index: 809
# Length of prefixes: 14500
# caption2embedding: 7613
# Item index: 7613
# Length of prefixes: 14500
# caption2embedding: 60
# Item index: 60
# Length of prefixes: 14500
# caption2embedding: 14489
# Item index: 14489
# Length of prefixes: 14500
# caption2embedding: 2766
# Item index: 2766
# Length of prefixes: 14500
# caption2embedding: 3915
# Item index: 3915
# Length of prefixes: 14500
# caption2embedding: 4404
# Item index: 4404
# Length of prefixes: 14500
# caption2embedding: 759
# Item index: 759
# coco_prefix:  92% 835/906 [08:58<00:45,  1.55it/s, loss=2.58]Length of prefixes: 14500
# caption2embedding: 4976
# Item index: 4976
# Length of prefixes: 14500
# caption2embedding: 9109
# Item index: 9109
# Length of prefixes: 14500
# caption2embedding: 4781
# Item index: 4781
# Length of prefixes: 14500
# caption2embedding: 8011
# Item index: 8011
# Length of prefixes: 14500
# caption2embedding: 1771
# Item index: 1771
# Length of prefixes: 14500
# caption2embedding: 1020
# Item index: 1020
# Length of prefixes: 14500
# caption2embedding: 12003
# Item index: 12003
# Length of prefixes: 14500
# caption2embedding: 7200
# Item index: 7200
# Length of prefixes: 14500
# caption2embedding: 12253
# Item index: 12253
# Length of prefixes: 14500
# caption2embedding: 10892
# Item index: 10892
# Length of prefixes: 14500
# caption2embedding: 7013
# Item index: 7013
# Length of prefixes: 14500
# caption2embedding: 3791
# Item index: 3791
# Length of prefixes: 14500
# caption2embedding: 10169
# Item index: 10169
# Length of prefixes: 14500
# caption2embedding: 10391
# Item index: 10391
# Length of prefixes: 14500
# caption2embedding: 1380
# Item index: 1380
# Length of prefixes: 14500
# caption2embedding: 9515
# Item index: 9515
# coco_prefix:  92% 836/906 [08:58<00:45,  1.55it/s, loss=2.56]Length of prefixes: 14500
# caption2embedding: 3268
# Item index: 3268
# Length of prefixes: 14500
# caption2embedding: 10254
# Item index: 10254
# Length of prefixes: 14500
# caption2embedding: 668
# Item index: 668
# Length of prefixes: 14500
# caption2embedding: 6913
# Item index: 6913
# Length of prefixes: 14500
# caption2embedding: 1705
# Item index: 1705
# Length of prefixes: 14500
# caption2embedding: 3075
# Item index: 3075
# Length of prefixes: 14500
# caption2embedding: 11010
# Item index: 11010
# Length of prefixes: 14500
# caption2embedding: 6740
# Item index: 6740
# Length of prefixes: 14500
# caption2embedding: 2060
# Item index: 2060
# Length of prefixes: 14500
# caption2embedding: 10486
# Item index: 10486
# Length of prefixes: 14500
# caption2embedding: 12047
# Item index: 12047
# Length of prefixes: 14500
# caption2embedding: 4764
# Item index: 4764
# Length of prefixes: 14500
# caption2embedding: 4961
# Item index: 4961
# Length of prefixes: 14500
# caption2embedding: 1246
# Item index: 1246
# Length of prefixes: 14500
# caption2embedding: 14417
# Item index: 14417
# Length of prefixes: 14500
# caption2embedding: 8726
# Item index: 8726
# coco_prefix:  92% 837/906 [08:59<00:44,  1.55it/s, loss=2.63]Length of prefixes: 14500
# caption2embedding: 538
# Item index: 538
# Length of prefixes: 14500
# caption2embedding: 12121
# Item index: 12121
# Length of prefixes: 14500
# caption2embedding: 748
# Item index: 748
# Length of prefixes: 14500
# caption2embedding: 6216
# Item index: 6216
# Length of prefixes: 14500
# caption2embedding: 12498
# Item index: 12498
# Length of prefixes: 14500
# caption2embedding: 2762
# Item index: 2762
# Length of prefixes: 14500
# caption2embedding: 11491
# Item index: 11491
# Length of prefixes: 14500
# caption2embedding: 6678
# Item index: 6678
# Length of prefixes: 14500
# caption2embedding: 14094
# Item index: 14094
# Length of prefixes: 14500
# caption2embedding: 1596
# Item index: 1596
# Length of prefixes: 14500
# caption2embedding: 1618
# Item index: 1618
# Length of prefixes: 14500
# caption2embedding: 7999
# Item index: 7999
# Length of prefixes: 14500
# caption2embedding: 2499
# Item index: 2499
# Length of prefixes: 14500
# caption2embedding: 10997
# Item index: 10997
# Length of prefixes: 14500
# caption2embedding: 9947
# Item index: 9947
# Length of prefixes: 14500
# caption2embedding: 10310
# Item index: 10310
# coco_prefix:  92% 838/906 [09:00<00:43,  1.55it/s, loss=2.27]Length of prefixes: 14500
# caption2embedding: 14333
# Item index: 14333
# Length of prefixes: 14500
# caption2embedding: 12470
# Item index: 12470
# Length of prefixes: 14500
# caption2embedding: 5593
# Item index: 5593
# Length of prefixes: 14500
# caption2embedding: 9962
# Item index: 9962
# Length of prefixes: 14500
# caption2embedding: 5801
# Item index: 5801
# Length of prefixes: 14500
# caption2embedding: 7660
# Item index: 7660
# Length of prefixes: 14500
# caption2embedding: 10950
# Item index: 10950
# Length of prefixes: 14500
# caption2embedding: 2604
# Item index: 2604
# Length of prefixes: 14500
# caption2embedding: 12581
# Item index: 12581
# Length of prefixes: 14500
# caption2embedding: 5230
# Item index: 5230
# Length of prefixes: 14500
# caption2embedding: 39
# Item index: 39
# Length of prefixes: 14500
# caption2embedding: 790
# Item index: 790
# Length of prefixes: 14500
# caption2embedding: 1426
# Item index: 1426
# Length of prefixes: 14500
# caption2embedding: 3003
# Item index: 3003
# Length of prefixes: 14500
# caption2embedding: 5711
# Item index: 5711
# Length of prefixes: 14500
# caption2embedding: 5294
# Item index: 5294
# coco_prefix:  93% 839/906 [09:00<00:43,  1.55it/s, loss=2.24]Length of prefixes: 14500
# caption2embedding: 4356
# Item index: 4356
# Length of prefixes: 14500
# caption2embedding: 4549
# Item index: 4549
# Length of prefixes: 14500
# caption2embedding: 1443
# Item index: 1443
# Length of prefixes: 14500
# caption2embedding: 5686
# Item index: 5686
# Length of prefixes: 14500
# caption2embedding: 6916
# Item index: 6916
# Length of prefixes: 14500
# caption2embedding: 7101
# Item index: 7101
# Length of prefixes: 14500
# caption2embedding: 13998
# Item index: 13998
# Length of prefixes: 14500
# caption2embedding: 6359
# Item index: 6359
# Length of prefixes: 14500
# caption2embedding: 8147
# Item index: 8147
# Length of prefixes: 14500
# caption2embedding: 11050
# Item index: 11050
# Length of prefixes: 14500
# caption2embedding: 3744
# Item index: 3744
# Length of prefixes: 14500
# caption2embedding: 7456
# Item index: 7456
# Length of prefixes: 14500
# caption2embedding: 4537
# Item index: 4537
# Length of prefixes: 14500
# caption2embedding: 13254
# Item index: 13254
# Length of prefixes: 14500
# caption2embedding: 271
# Item index: 271
# Length of prefixes: 14500
# caption2embedding: 10992
# Item index: 10992
# coco_prefix:  93% 840/906 [09:01<00:42,  1.55it/s, loss=2.76]Length of prefixes: 14500
# caption2embedding: 14207
# Item index: 14207
# Length of prefixes: 14500
# caption2embedding: 3558
# Item index: 3558
# Length of prefixes: 14500
# caption2embedding: 4707
# Item index: 4707
# Length of prefixes: 14500
# caption2embedding: 1493
# Item index: 1493
# Length of prefixes: 14500
# caption2embedding: 11258
# Item index: 11258
# Length of prefixes: 14500
# caption2embedding: 2860
# Item index: 2860
# Length of prefixes: 14500
# caption2embedding: 11558
# Item index: 11558
# Length of prefixes: 14500
# caption2embedding: 511
# Item index: 511
# Length of prefixes: 14500
# caption2embedding: 13605
# Item index: 13605
# Length of prefixes: 14500
# caption2embedding: 5203
# Item index: 5203
# Length of prefixes: 14500
# caption2embedding: 9466
# Item index: 9466
# Length of prefixes: 14500
# caption2embedding: 6263
# Item index: 6263
# Length of prefixes: 14500
# caption2embedding: 10394
# Item index: 10394
# Length of prefixes: 14500
# caption2embedding: 3535
# Item index: 3535
# Length of prefixes: 14500
# caption2embedding: 8931
# Item index: 8931
# Length of prefixes: 14500
# caption2embedding: 10131
# Item index: 10131
# coco_prefix:  93% 841/906 [09:02<00:41,  1.55it/s, loss=2.57]Length of prefixes: 14500
# caption2embedding: 675
# Item index: 675
# Length of prefixes: 14500
# caption2embedding: 10343
# Item index: 10343
# Length of prefixes: 14500
# caption2embedding: 1707
# Item index: 1707
# Length of prefixes: 14500
# caption2embedding: 3343
# Item index: 3343
# Length of prefixes: 14500
# caption2embedding: 10087
# Item index: 10087
# Length of prefixes: 14500
# caption2embedding: 4657
# Item index: 4657
# Length of prefixes: 14500
# caption2embedding: 7772
# Item index: 7772
# Length of prefixes: 14500
# caption2embedding: 3638
# Item index: 3638
# Length of prefixes: 14500
# caption2embedding: 1722
# Item index: 1722
# Length of prefixes: 14500
# caption2embedding: 2944
# Item index: 2944
# Length of prefixes: 14500
# caption2embedding: 6772
# Item index: 6772
# Length of prefixes: 14500
# caption2embedding: 4108
# Item index: 4108
# Length of prefixes: 14500
# caption2embedding: 8467
# Item index: 8467
# Length of prefixes: 14500
# caption2embedding: 9783
# Item index: 9783
# Length of prefixes: 14500
# caption2embedding: 13
# Item index: 13
# Length of prefixes: 14500
# caption2embedding: 6109
# Item index: 6109
# coco_prefix:  93% 842/906 [09:02<00:41,  1.55it/s, loss=2.2]Length of prefixes: 14500
# caption2embedding: 8216
# Item index: 8216
# Length of prefixes: 14500
# caption2embedding: 9191
# Item index: 9191
# Length of prefixes: 14500
# caption2embedding: 8900
# Item index: 8900
# Length of prefixes: 14500
# caption2embedding: 182
# Item index: 182
# Length of prefixes: 14500
# caption2embedding: 11225
# Item index: 11225
# Length of prefixes: 14500
# caption2embedding: 4065
# Item index: 4065
# Length of prefixes: 14500
# caption2embedding: 7563
# Item index: 7563
# Length of prefixes: 14500
# caption2embedding: 7963
# Item index: 7963
# Length of prefixes: 14500
# caption2embedding: 8677
# Item index: 8677
# Length of prefixes: 14500
# caption2embedding: 4121
# Item index: 4121
# Length of prefixes: 14500
# caption2embedding: 3052
# Item index: 3052
# Length of prefixes: 14500
# caption2embedding: 9199
# Item index: 9199
# Length of prefixes: 14500
# caption2embedding: 13438
# Item index: 13438
# Length of prefixes: 14500
# caption2embedding: 653
# Item index: 653
# Length of prefixes: 14500
# caption2embedding: 13810
# Item index: 13810
# Length of prefixes: 14500
# caption2embedding: 14487
# Item index: 14487
# coco_prefix:  93% 843/906 [09:03<00:40,  1.55it/s, loss=2.42]Length of prefixes: 14500
# caption2embedding: 12980
# Item index: 12980
# Length of prefixes: 14500
# caption2embedding: 226
# Item index: 226
# Length of prefixes: 14500
# caption2embedding: 1822
# Item index: 1822
# Length of prefixes: 14500
# caption2embedding: 9996
# Item index: 9996
# Length of prefixes: 14500
# caption2embedding: 13752
# Item index: 13752
# Length of prefixes: 14500
# caption2embedding: 1803
# Item index: 1803
# Length of prefixes: 14500
# caption2embedding: 9889
# Item index: 9889
# Length of prefixes: 14500
# caption2embedding: 3354
# Item index: 3354
# Length of prefixes: 14500
# caption2embedding: 6100
# Item index: 6100
# Length of prefixes: 14500
# caption2embedding: 3346
# Item index: 3346
# Length of prefixes: 14500
# caption2embedding: 5465
# Item index: 5465
# Length of prefixes: 14500
# caption2embedding: 12719
# Item index: 12719
# Length of prefixes: 14500
# caption2embedding: 11281
# Item index: 11281
# Length of prefixes: 14500
# caption2embedding: 10786
# Item index: 10786
# Length of prefixes: 14500
# caption2embedding: 5606
# Item index: 5606
# Length of prefixes: 14500
# caption2embedding: 345
# Item index: 345
# coco_prefix:  93% 844/906 [09:04<00:39,  1.55it/s, loss=2.63]Length of prefixes: 14500
# caption2embedding: 4625
# Item index: 4625
# Length of prefixes: 14500
# caption2embedding: 7988
# Item index: 7988
# Length of prefixes: 14500
# caption2embedding: 3756
# Item index: 3756
# Length of prefixes: 14500
# caption2embedding: 9237
# Item index: 9237
# Length of prefixes: 14500
# caption2embedding: 4113
# Item index: 4113
# Length of prefixes: 14500
# caption2embedding: 8433
# Item index: 8433
# Length of prefixes: 14500
# caption2embedding: 8269
# Item index: 8269
# Length of prefixes: 14500
# caption2embedding: 3727
# Item index: 3727
# Length of prefixes: 14500
# caption2embedding: 8038
# Item index: 8038
# Length of prefixes: 14500
# caption2embedding: 5083
# Item index: 5083
# Length of prefixes: 14500
# caption2embedding: 5024
# Item index: 5024
# Length of prefixes: 14500
# caption2embedding: 4169
# Item index: 4169
# Length of prefixes: 14500
# caption2embedding: 14371
# Item index: 14371
# Length of prefixes: 14500
# caption2embedding: 3532
# Item index: 3532
# Length of prefixes: 14500
# caption2embedding: 10049
# Item index: 10049
# Length of prefixes: 14500
# caption2embedding: 14164
# Item index: 14164
# coco_prefix:  93% 845/906 [09:04<00:39,  1.55it/s, loss=2.59]Length of prefixes: 14500
# caption2embedding: 11447
# Item index: 11447
# Length of prefixes: 14500
# caption2embedding: 5696
# Item index: 5696
# Length of prefixes: 14500
# caption2embedding: 4884
# Item index: 4884
# Length of prefixes: 14500
# caption2embedding: 190
# Item index: 190
# Length of prefixes: 14500
# caption2embedding: 10316
# Item index: 10316
# Length of prefixes: 14500
# caption2embedding: 5158
# Item index: 5158
# Length of prefixes: 14500
# caption2embedding: 3821
# Item index: 3821
# Length of prefixes: 14500
# caption2embedding: 11172
# Item index: 11172
# Length of prefixes: 14500
# caption2embedding: 5048
# Item index: 5048
# Length of prefixes: 14500
# caption2embedding: 14069
# Item index: 14069
# Length of prefixes: 14500
# caption2embedding: 4885
# Item index: 4885
# Length of prefixes: 14500
# caption2embedding: 3934
# Item index: 3934
# Length of prefixes: 14500
# caption2embedding: 3982
# Item index: 3982
# Length of prefixes: 14500
# caption2embedding: 7937
# Item index: 7937
# Length of prefixes: 14500
# caption2embedding: 2425
# Item index: 2425
# Length of prefixes: 14500
# caption2embedding: 12116
# Item index: 12116
# coco_prefix:  93% 846/906 [09:05<00:38,  1.55it/s, loss=2.74]Length of prefixes: 14500
# caption2embedding: 6286
# Item index: 6286
# Length of prefixes: 14500
# caption2embedding: 14400
# Item index: 14400
# Length of prefixes: 14500
# caption2embedding: 11851
# Item index: 11851
# Length of prefixes: 14500
# caption2embedding: 12872
# Item index: 12872
# Length of prefixes: 14500
# caption2embedding: 10760
# Item index: 10760
# Length of prefixes: 14500
# caption2embedding: 8968
# Item index: 8968
# Length of prefixes: 14500
# caption2embedding: 1595
# Item index: 1595
# Length of prefixes: 14500
# caption2embedding: 3639
# Item index: 3639
# Length of prefixes: 14500
# caption2embedding: 4913
# Item index: 4913
# Length of prefixes: 14500
# caption2embedding: 22
# Item index: 22
# Length of prefixes: 14500
# caption2embedding: 14406
# Item index: 14406
# Length of prefixes: 14500
# caption2embedding: 8437
# Item index: 8437
# Length of prefixes: 14500
# caption2embedding: 13076
# Item index: 13076
# Length of prefixes: 14500
# caption2embedding: 7233
# Item index: 7233
# Length of prefixes: 14500
# caption2embedding: 13599
# Item index: 13599
# Length of prefixes: 14500
# caption2embedding: 3632
# Item index: 3632
# coco_prefix:  93% 847/906 [09:06<00:38,  1.55it/s, loss=2.48]Length of prefixes: 14500
# caption2embedding: 11268
# Item index: 11268
# Length of prefixes: 14500
# caption2embedding: 10903
# Item index: 10903
# Length of prefixes: 14500
# caption2embedding: 8722
# Item index: 8722
# Length of prefixes: 14500
# caption2embedding: 576
# Item index: 576
# Length of prefixes: 14500
# caption2embedding: 645
# Item index: 645
# Length of prefixes: 14500
# caption2embedding: 3529
# Item index: 3529
# Length of prefixes: 14500
# caption2embedding: 11841
# Item index: 11841
# Length of prefixes: 14500
# caption2embedding: 1430
# Item index: 1430
# Length of prefixes: 14500
# caption2embedding: 13096
# Item index: 13096
# Length of prefixes: 14500
# caption2embedding: 8889
# Item index: 8889
# Length of prefixes: 14500
# caption2embedding: 12680
# Item index: 12680
# Length of prefixes: 14500
# caption2embedding: 3384
# Item index: 3384
# Length of prefixes: 14500
# caption2embedding: 8500
# Item index: 8500
# Length of prefixes: 14500
# caption2embedding: 9485
# Item index: 9485
# Length of prefixes: 14500
# caption2embedding: 1408
# Item index: 1408
# Length of prefixes: 14500
# caption2embedding: 3538
# Item index: 3538
# coco_prefix:  94% 848/906 [09:06<00:37,  1.55it/s, loss=2.38]Length of prefixes: 14500
# caption2embedding: 12113
# Item index: 12113
# Length of prefixes: 14500
# caption2embedding: 14434
# Item index: 14434
# Length of prefixes: 14500
# caption2embedding: 6704
# Item index: 6704
# Length of prefixes: 14500
# caption2embedding: 8855
# Item index: 8855
# Length of prefixes: 14500
# caption2embedding: 4264
# Item index: 4264
# Length of prefixes: 14500
# caption2embedding: 7843
# Item index: 7843
# Length of prefixes: 14500
# caption2embedding: 687
# Item index: 687
# Length of prefixes: 14500
# caption2embedding: 11836
# Item index: 11836
# Length of prefixes: 14500
# caption2embedding: 8736
# Item index: 8736
# Length of prefixes: 14500
# caption2embedding: 1750
# Item index: 1750
# Length of prefixes: 14500
# caption2embedding: 9058
# Item index: 9058
# Length of prefixes: 14500
# caption2embedding: 13073
# Item index: 13073
# Length of prefixes: 14500
# caption2embedding: 4912
# Item index: 4912
# Length of prefixes: 14500
# caption2embedding: 4830
# Item index: 4830
# Length of prefixes: 14500
# caption2embedding: 6747
# Item index: 6747
# Length of prefixes: 14500
# caption2embedding: 13066
# Item index: 13066
# coco_prefix:  94% 849/906 [09:07<00:36,  1.55it/s, loss=2.6]Length of prefixes: 14500
# caption2embedding: 7864
# Item index: 7864
# Length of prefixes: 14500
# caption2embedding: 2856
# Item index: 2856
# Length of prefixes: 14500
# caption2embedding: 12456
# Item index: 12456
# Length of prefixes: 14500
# caption2embedding: 8575
# Item index: 8575
# Length of prefixes: 14500
# caption2embedding: 4862
# Item index: 4862
# Length of prefixes: 14500
# caption2embedding: 13961
# Item index: 13961
# Length of prefixes: 14500
# caption2embedding: 6036
# Item index: 6036
# Length of prefixes: 14500
# caption2embedding: 13695
# Item index: 13695
# Length of prefixes: 14500
# caption2embedding: 3765
# Item index: 3765
# Length of prefixes: 14500
# caption2embedding: 5688
# Item index: 5688
# Length of prefixes: 14500
# caption2embedding: 12261
# Item index: 12261
# Length of prefixes: 14500
# caption2embedding: 1977
# Item index: 1977
# Length of prefixes: 14500
# caption2embedding: 8449
# Item index: 8449
# Length of prefixes: 14500
# caption2embedding: 12751
# Item index: 12751
# Length of prefixes: 14500
# caption2embedding: 6819
# Item index: 6819
# Length of prefixes: 14500
# caption2embedding: 8507
# Item index: 8507
# coco_prefix:  94% 850/906 [09:08<00:36,  1.55it/s, loss=2.47]Length of prefixes: 14500
# caption2embedding: 3056
# Item index: 3056
# Length of prefixes: 14500
# caption2embedding: 4365
# Item index: 4365
# Length of prefixes: 14500
# caption2embedding: 12631
# Item index: 12631
# Length of prefixes: 14500
# caption2embedding: 14480
# Item index: 14480
# Length of prefixes: 14500
# caption2embedding: 8348
# Item index: 8348
# Length of prefixes: 14500
# caption2embedding: 1185
# Item index: 1185
# Length of prefixes: 14500
# caption2embedding: 5689
# Item index: 5689
# Length of prefixes: 14500
# caption2embedding: 7573
# Item index: 7573
# Length of prefixes: 14500
# caption2embedding: 8758
# Item index: 8758
# Length of prefixes: 14500
# caption2embedding: 4801
# Item index: 4801
# Length of prefixes: 14500
# caption2embedding: 9600
# Item index: 9600
# Length of prefixes: 14500
# caption2embedding: 10459
# Item index: 10459
# Length of prefixes: 14500
# caption2embedding: 6345
# Item index: 6345
# Length of prefixes: 14500
# caption2embedding: 13289
# Item index: 13289
# Length of prefixes: 14500
# caption2embedding: 2526
# Item index: 2526
# Length of prefixes: 14500
# caption2embedding: 5938
# Item index: 5938
# coco_prefix:  94% 851/906 [09:08<00:35,  1.55it/s, loss=2.19]Length of prefixes: 14500
# caption2embedding: 4443
# Item index: 4443
# Length of prefixes: 14500
# caption2embedding: 9088
# Item index: 9088
# Length of prefixes: 14500
# caption2embedding: 5724
# Item index: 5724
# Length of prefixes: 14500
# caption2embedding: 11116
# Item index: 11116
# Length of prefixes: 14500
# caption2embedding: 9257
# Item index: 9257
# Length of prefixes: 14500
# caption2embedding: 5096
# Item index: 5096
# Length of prefixes: 14500
# caption2embedding: 8984
# Item index: 8984
# Length of prefixes: 14500
# caption2embedding: 4636
# Item index: 4636
# Length of prefixes: 14500
# caption2embedding: 852
# Item index: 852
# Length of prefixes: 14500
# caption2embedding: 13102
# Item index: 13102
# Length of prefixes: 14500
# caption2embedding: 1194
# Item index: 1194
# Length of prefixes: 14500
# caption2embedding: 11901
# Item index: 11901
# Length of prefixes: 14500
# caption2embedding: 5078
# Item index: 5078
# Length of prefixes: 14500
# caption2embedding: 7287
# Item index: 7287
# Length of prefixes: 14500
# caption2embedding: 6490
# Item index: 6490
# Length of prefixes: 14500
# caption2embedding: 5486
# Item index: 5486
# coco_prefix:  94% 852/906 [09:09<00:34,  1.54it/s, loss=2.41]Length of prefixes: 14500
# caption2embedding: 10949
# Item index: 10949
# Length of prefixes: 14500
# caption2embedding: 3975
# Item index: 3975
# Length of prefixes: 14500
# caption2embedding: 4461
# Item index: 4461
# Length of prefixes: 14500
# caption2embedding: 8187
# Item index: 8187
# Length of prefixes: 14500
# caption2embedding: 11699
# Item index: 11699
# Length of prefixes: 14500
# caption2embedding: 7098
# Item index: 7098
# Length of prefixes: 14500
# caption2embedding: 2150
# Item index: 2150
# Length of prefixes: 14500
# caption2embedding: 6323
# Item index: 6323
# Length of prefixes: 14500
# caption2embedding: 5371
# Item index: 5371
# Length of prefixes: 14500
# caption2embedding: 9778
# Item index: 9778
# Length of prefixes: 14500
# caption2embedding: 5410
# Item index: 5410
# Length of prefixes: 14500
# caption2embedding: 8425
# Item index: 8425
# Length of prefixes: 14500
# caption2embedding: 13500
# Item index: 13500
# Length of prefixes: 14500
# caption2embedding: 1717
# Item index: 1717
# Length of prefixes: 14500
# caption2embedding: 4925
# Item index: 4925
# Length of prefixes: 14500
# caption2embedding: 9860
# Item index: 9860
# coco_prefix:  94% 853/906 [09:09<00:34,  1.55it/s, loss=2.78]Length of prefixes: 14500
# caption2embedding: 10036
# Item index: 10036
# Length of prefixes: 14500
# caption2embedding: 7599
# Item index: 7599
# Length of prefixes: 14500
# caption2embedding: 12610
# Item index: 12610
# Length of prefixes: 14500
# caption2embedding: 4
# Item index: 4
# Length of prefixes: 14500
# caption2embedding: 8199
# Item index: 8199
# Length of prefixes: 14500
# caption2embedding: 9527
# Item index: 9527
# Length of prefixes: 14500
# caption2embedding: 13584
# Item index: 13584
# Length of prefixes: 14500
# caption2embedding: 2327
# Item index: 2327
# Length of prefixes: 14500
# caption2embedding: 11146
# Item index: 11146
# Length of prefixes: 14500
# caption2embedding: 13041
# Item index: 13041
# Length of prefixes: 14500
# caption2embedding: 1558
# Item index: 1558
# Length of prefixes: 14500
# caption2embedding: 3001
# Item index: 3001
# Length of prefixes: 14500
# caption2embedding: 1521
# Item index: 1521
# Length of prefixes: 14500
# caption2embedding: 6112
# Item index: 6112
# Length of prefixes: 14500
# caption2embedding: 14187
# Item index: 14187
# Length of prefixes: 14500
# caption2embedding: 14079
# Item index: 14079
# coco_prefix:  94% 854/906 [09:10<00:33,  1.55it/s, loss=2.51]Length of prefixes: 14500
# caption2embedding: 14325
# Item index: 14325
# Length of prefixes: 14500
# caption2embedding: 4269
# Item index: 4269
# Length of prefixes: 14500
# caption2embedding: 14065
# Item index: 14065
# Length of prefixes: 14500
# caption2embedding: 6002
# Item index: 6002
# Length of prefixes: 14500
# caption2embedding: 8042
# Item index: 8042
# Length of prefixes: 14500
# caption2embedding: 13245
# Item index: 13245
# Length of prefixes: 14500
# caption2embedding: 6422
# Item index: 6422
# Length of prefixes: 14500
# caption2embedding: 14066
# Item index: 14066
# Length of prefixes: 14500
# caption2embedding: 1807
# Item index: 1807
# Length of prefixes: 14500
# caption2embedding: 298
# Item index: 298
# Length of prefixes: 14500
# caption2embedding: 12602
# Item index: 12602
# Length of prefixes: 14500
# caption2embedding: 5329
# Item index: 5329
# Length of prefixes: 14500
# caption2embedding: 266
# Item index: 266
# Length of prefixes: 14500
# caption2embedding: 7039
# Item index: 7039
# Length of prefixes: 14500
# caption2embedding: 3074
# Item index: 3074
# Length of prefixes: 14500
# caption2embedding: 12764
# Item index: 12764
# coco_prefix:  94% 855/906 [09:11<00:32,  1.55it/s, loss=2.34]Length of prefixes: 14500
# caption2embedding: 9465
# Item index: 9465
# Length of prefixes: 14500
# caption2embedding: 12836
# Item index: 12836
# Length of prefixes: 14500
# caption2embedding: 4654
# Item index: 4654
# Length of prefixes: 14500
# caption2embedding: 6637
# Item index: 6637
# Length of prefixes: 14500
# caption2embedding: 631
# Item index: 631
# Length of prefixes: 14500
# caption2embedding: 11254
# Item index: 11254
# Length of prefixes: 14500
# caption2embedding: 13813
# Item index: 13813
# Length of prefixes: 14500
# caption2embedding: 8133
# Item index: 8133
# Length of prefixes: 14500
# caption2embedding: 6432
# Item index: 6432
# Length of prefixes: 14500
# caption2embedding: 5263
# Item index: 5263
# Length of prefixes: 14500
# caption2embedding: 3279
# Item index: 3279
# Length of prefixes: 14500
# caption2embedding: 9207
# Item index: 9207
# Length of prefixes: 14500
# caption2embedding: 10833
# Item index: 10833
# Length of prefixes: 14500
# caption2embedding: 5960
# Item index: 5960
# Length of prefixes: 14500
# caption2embedding: 7520
# Item index: 7520
# Length of prefixes: 14500
# caption2embedding: 8013
# Item index: 8013
# coco_prefix:  94% 856/906 [09:11<00:32,  1.55it/s, loss=2.53]Length of prefixes: 14500
# caption2embedding: 2132
# Item index: 2132
# Length of prefixes: 14500
# caption2embedding: 1924
# Item index: 1924
# Length of prefixes: 14500
# caption2embedding: 1551
# Item index: 1551
# Length of prefixes: 14500
# caption2embedding: 10688
# Item index: 10688
# Length of prefixes: 14500
# caption2embedding: 10508
# Item index: 10508
# Length of prefixes: 14500
# caption2embedding: 1892
# Item index: 1892
# Length of prefixes: 14500
# caption2embedding: 13267
# Item index: 13267
# Length of prefixes: 14500
# caption2embedding: 9922
# Item index: 9922
# Length of prefixes: 14500
# caption2embedding: 14014
# Item index: 14014
# Length of prefixes: 14500
# caption2embedding: 2204
# Item index: 2204
# Length of prefixes: 14500
# caption2embedding: 7137
# Item index: 7137
# Length of prefixes: 14500
# caption2embedding: 14284
# Item index: 14284
# Length of prefixes: 14500
# caption2embedding: 2303
# Item index: 2303
# Length of prefixes: 14500
# caption2embedding: 7207
# Item index: 7207
# Length of prefixes: 14500
# caption2embedding: 7748
# Item index: 7748
# Length of prefixes: 14500
# caption2embedding: 1798
# Item index: 1798
# coco_prefix:  95% 857/906 [09:12<00:31,  1.55it/s, loss=2.16]Length of prefixes: 14500
# caption2embedding: 2837
# Item index: 2837
# Length of prefixes: 14500
# caption2embedding: 3168
# Item index: 3168
# Length of prefixes: 14500
# caption2embedding: 10381
# Item index: 10381
# Length of prefixes: 14500
# caption2embedding: 9500
# Item index: 9500
# Length of prefixes: 14500
# caption2embedding: 11829
# Item index: 11829
# Length of prefixes: 14500
# caption2embedding: 13244
# Item index: 13244
# Length of prefixes: 14500
# caption2embedding: 13503
# Item index: 13503
# Length of prefixes: 14500
# caption2embedding: 1169
# Item index: 1169
# Length of prefixes: 14500
# caption2embedding: 12923
# Item index: 12923
# Length of prefixes: 14500
# caption2embedding: 3372
# Item index: 3372
# Length of prefixes: 14500
# caption2embedding: 10225
# Item index: 10225
# Length of prefixes: 14500
# caption2embedding: 2622
# Item index: 2622
# Length of prefixes: 14500
# caption2embedding: 10067
# Item index: 10067
# Length of prefixes: 14500
# caption2embedding: 5589
# Item index: 5589
# Length of prefixes: 14500
# caption2embedding: 8883
# Item index: 8883
# Length of prefixes: 14500
# caption2embedding: 3961
# Item index: 3961
# coco_prefix:  95% 858/906 [09:13<00:30,  1.55it/s, loss=2.45]Length of prefixes: 14500
# caption2embedding: 3596
# Item index: 3596
# Length of prefixes: 14500
# caption2embedding: 3362
# Item index: 3362
# Length of prefixes: 14500
# caption2embedding: 2988
# Item index: 2988
# Length of prefixes: 14500
# caption2embedding: 1638
# Item index: 1638
# Length of prefixes: 14500
# caption2embedding: 3417
# Item index: 3417
# Length of prefixes: 14500
# caption2embedding: 11394
# Item index: 11394
# Length of prefixes: 14500
# caption2embedding: 2731
# Item index: 2731
# Length of prefixes: 14500
# caption2embedding: 13919
# Item index: 13919
# Length of prefixes: 14500
# caption2embedding: 7852
# Item index: 7852
# Length of prefixes: 14500
# caption2embedding: 6893
# Item index: 6893
# Length of prefixes: 14500
# caption2embedding: 10704
# Item index: 10704
# Length of prefixes: 14500
# caption2embedding: 609
# Item index: 609
# Length of prefixes: 14500
# caption2embedding: 6136
# Item index: 6136
# Length of prefixes: 14500
# caption2embedding: 719
# Item index: 719
# Length of prefixes: 14500
# caption2embedding: 3140
# Item index: 3140
# Length of prefixes: 14500
# caption2embedding: 9116
# Item index: 9116
# coco_prefix:  95% 859/906 [09:13<00:30,  1.55it/s, loss=2.2]Length of prefixes: 14500
# caption2embedding: 8142
# Item index: 8142
# Length of prefixes: 14500
# caption2embedding: 11101
# Item index: 11101
# Length of prefixes: 14500
# caption2embedding: 525
# Item index: 525
# Length of prefixes: 14500
# caption2embedding: 8461
# Item index: 8461
# Length of prefixes: 14500
# caption2embedding: 6167
# Item index: 6167
# Length of prefixes: 14500
# caption2embedding: 5288
# Item index: 5288
# Length of prefixes: 14500
# caption2embedding: 6905
# Item index: 6905
# Length of prefixes: 14500
# caption2embedding: 12236
# Item index: 12236
# Length of prefixes: 14500
# caption2embedding: 1424
# Item index: 1424
# Length of prefixes: 14500
# caption2embedding: 6778
# Item index: 6778
# Length of prefixes: 14500
# caption2embedding: 14018
# Item index: 14018
# Length of prefixes: 14500
# caption2embedding: 5411
# Item index: 5411
# Length of prefixes: 14500
# caption2embedding: 2444
# Item index: 2444
# Length of prefixes: 14500
# caption2embedding: 4019
# Item index: 4019
# Length of prefixes: 14500
# caption2embedding: 546
# Item index: 546
# Length of prefixes: 14500
# caption2embedding: 6045
# Item index: 6045
# coco_prefix:  95% 860/906 [09:14<00:29,  1.55it/s, loss=2.32]Length of prefixes: 14500
# caption2embedding: 509
# Item index: 509
# Length of prefixes: 14500
# caption2embedding: 12101
# Item index: 12101
# Length of prefixes: 14500
# caption2embedding: 14444
# Item index: 14444
# Length of prefixes: 14500
# caption2embedding: 8001
# Item index: 8001
# Length of prefixes: 14500
# caption2embedding: 10444
# Item index: 10444
# Length of prefixes: 14500
# caption2embedding: 9362
# Item index: 9362
# Length of prefixes: 14500
# caption2embedding: 12025
# Item index: 12025
# Length of prefixes: 14500
# caption2embedding: 2501
# Item index: 2501
# Length of prefixes: 14500
# caption2embedding: 6305
# Item index: 6305
# Length of prefixes: 14500
# caption2embedding: 998
# Item index: 998
# Length of prefixes: 14500
# caption2embedding: 1238
# Item index: 1238
# Length of prefixes: 14500
# caption2embedding: 10717
# Item index: 10717
# Length of prefixes: 14500
# caption2embedding: 4612
# Item index: 4612
# Length of prefixes: 14500
# caption2embedding: 10482
# Item index: 10482
# Length of prefixes: 14500
# caption2embedding: 11153
# Item index: 11153
# Length of prefixes: 14500
# caption2embedding: 3987
# Item index: 3987
# coco_prefix:  95% 861/906 [09:15<00:28,  1.55it/s, loss=2.54]Length of prefixes: 14500
# caption2embedding: 9533
# Item index: 9533
# Length of prefixes: 14500
# caption2embedding: 10243
# Item index: 10243
# Length of prefixes: 14500
# caption2embedding: 12351
# Item index: 12351
# Length of prefixes: 14500
# caption2embedding: 4069
# Item index: 4069
# Length of prefixes: 14500
# caption2embedding: 3187
# Item index: 3187
# Length of prefixes: 14500
# caption2embedding: 1492
# Item index: 1492
# Length of prefixes: 14500
# caption2embedding: 8978
# Item index: 8978
# Length of prefixes: 14500
# caption2embedding: 8203
# Item index: 8203
# Length of prefixes: 14500
# caption2embedding: 9436
# Item index: 9436
# Length of prefixes: 14500
# caption2embedding: 13206
# Item index: 13206
# Length of prefixes: 14500
# caption2embedding: 12179
# Item index: 12179
# Length of prefixes: 14500
# caption2embedding: 8156
# Item index: 8156
# Length of prefixes: 14500
# caption2embedding: 3850
# Item index: 3850
# Length of prefixes: 14500
# caption2embedding: 13114
# Item index: 13114
# Length of prefixes: 14500
# caption2embedding: 2517
# Item index: 2517
# Length of prefixes: 14500
# caption2embedding: 8901
# Item index: 8901
# coco_prefix:  95% 862/906 [09:15<00:28,  1.56it/s, loss=2.55]Length of prefixes: 14500
# caption2embedding: 9445
# Item index: 9445
# Length of prefixes: 14500
# caption2embedding: 14049
# Item index: 14049
# Length of prefixes: 14500
# caption2embedding: 5596
# Item index: 5596
# Length of prefixes: 14500
# caption2embedding: 14405
# Item index: 14405
# Length of prefixes: 14500
# caption2embedding: 9386
# Item index: 9386
# Length of prefixes: 14500
# caption2embedding: 4949
# Item index: 4949
# Length of prefixes: 14500
# caption2embedding: 8795
# Item index: 8795
# Length of prefixes: 14500
# caption2embedding: 13701
# Item index: 13701
# Length of prefixes: 14500
# caption2embedding: 4611
# Item index: 4611
# Length of prefixes: 14500
# caption2embedding: 5327
# Item index: 5327
# Length of prefixes: 14500
# caption2embedding: 1824
# Item index: 1824
# Length of prefixes: 14500
# caption2embedding: 6093
# Item index: 6093
# Length of prefixes: 14500
# caption2embedding: 11422
# Item index: 11422
# Length of prefixes: 14500
# caption2embedding: 5845
# Item index: 5845
# Length of prefixes: 14500
# caption2embedding: 12014
# Item index: 12014
# Length of prefixes: 14500
# caption2embedding: 12264
# Item index: 12264
# coco_prefix:  95% 863/906 [09:16<00:27,  1.55it/s, loss=2.28]Length of prefixes: 14500
# caption2embedding: 923
# Item index: 923
# Length of prefixes: 14500
# caption2embedding: 11936
# Item index: 11936
# Length of prefixes: 14500
# caption2embedding: 9297
# Item index: 9297
# Length of prefixes: 14500
# caption2embedding: 585
# Item index: 585
# Length of prefixes: 14500
# caption2embedding: 4073
# Item index: 4073
# Length of prefixes: 14500
# caption2embedding: 4234
# Item index: 4234
# Length of prefixes: 14500
# caption2embedding: 12487
# Item index: 12487
# Length of prefixes: 14500
# caption2embedding: 11838
# Item index: 11838
# Length of prefixes: 14500
# caption2embedding: 2819
# Item index: 2819
# Length of prefixes: 14500
# caption2embedding: 9069
# Item index: 9069
# Length of prefixes: 14500
# caption2embedding: 6515
# Item index: 6515
# Length of prefixes: 14500
# caption2embedding: 14230
# Item index: 14230
# Length of prefixes: 14500
# caption2embedding: 10287
# Item index: 10287
# Length of prefixes: 14500
# caption2embedding: 2443
# Item index: 2443
# Length of prefixes: 14500
# caption2embedding: 4951
# Item index: 4951
# Length of prefixes: 14500
# caption2embedding: 12573
# Item index: 12573
# coco_prefix:  95% 864/906 [09:17<00:27,  1.55it/s, loss=2.62]Length of prefixes: 14500
# caption2embedding: 13143
# Item index: 13143
# Length of prefixes: 14500
# caption2embedding: 10100
# Item index: 10100
# Length of prefixes: 14500
# caption2embedding: 9421
# Item index: 9421
# Length of prefixes: 14500
# caption2embedding: 866
# Item index: 866
# Length of prefixes: 14500
# caption2embedding: 8178
# Item index: 8178
# Length of prefixes: 14500
# caption2embedding: 3444
# Item index: 3444
# Length of prefixes: 14500
# caption2embedding: 3440
# Item index: 3440
# Length of prefixes: 14500
# caption2embedding: 13410
# Item index: 13410
# Length of prefixes: 14500
# caption2embedding: 4767
# Item index: 4767
# Length of prefixes: 14500
# caption2embedding: 13853
# Item index: 13853
# Length of prefixes: 14500
# caption2embedding: 3047
# Item index: 3047
# Length of prefixes: 14500
# caption2embedding: 586
# Item index: 586
# Length of prefixes: 14500
# caption2embedding: 13475
# Item index: 13475
# Length of prefixes: 14500
# caption2embedding: 3391
# Item index: 3391
# Length of prefixes: 14500
# caption2embedding: 11135
# Item index: 11135
# Length of prefixes: 14500
# caption2embedding: 12711
# Item index: 12711
# coco_prefix:  95% 865/906 [09:17<00:26,  1.55it/s, loss=2.32]Length of prefixes: 14500
# caption2embedding: 7131
# Item index: 7131
# Length of prefixes: 14500
# caption2embedding: 8295
# Item index: 8295
# Length of prefixes: 14500
# caption2embedding: 2220
# Item index: 2220
# Length of prefixes: 14500
# caption2embedding: 4633
# Item index: 4633
# Length of prefixes: 14500
# caption2embedding: 11284
# Item index: 11284
# Length of prefixes: 14500
# caption2embedding: 408
# Item index: 408
# Length of prefixes: 14500
# caption2embedding: 6364
# Item index: 6364
# Length of prefixes: 14500
# caption2embedding: 11648
# Item index: 11648
# Length of prefixes: 14500
# caption2embedding: 14130
# Item index: 14130
# Length of prefixes: 14500
# caption2embedding: 14376
# Item index: 14376
# Length of prefixes: 14500
# caption2embedding: 4417
# Item index: 4417
# Length of prefixes: 14500
# caption2embedding: 5987
# Item index: 5987
# Length of prefixes: 14500
# caption2embedding: 9277
# Item index: 9277
# Length of prefixes: 14500
# caption2embedding: 13315
# Item index: 13315
# Length of prefixes: 14500
# caption2embedding: 3541
# Item index: 3541
# Length of prefixes: 14500
# caption2embedding: 13139
# Item index: 13139
# coco_prefix:  96% 866/906 [09:18<00:25,  1.55it/s, loss=2.35]Length of prefixes: 14500
# caption2embedding: 5110
# Item index: 5110
# Length of prefixes: 14500
# caption2embedding: 1539
# Item index: 1539
# Length of prefixes: 14500
# caption2embedding: 5405
# Item index: 5405
# Length of prefixes: 14500
# caption2embedding: 3484
# Item index: 3484
# Length of prefixes: 14500
# caption2embedding: 5681
# Item index: 5681
# Length of prefixes: 14500
# caption2embedding: 14189
# Item index: 14189
# Length of prefixes: 14500
# caption2embedding: 6931
# Item index: 6931
# Length of prefixes: 14500
# caption2embedding: 4977
# Item index: 4977
# Length of prefixes: 14500
# caption2embedding: 9994
# Item index: 9994
# Length of prefixes: 14500
# caption2embedding: 5317
# Item index: 5317
# Length of prefixes: 14500
# caption2embedding: 5394
# Item index: 5394
# Length of prefixes: 14500
# caption2embedding: 9310
# Item index: 9310
# Length of prefixes: 14500
# caption2embedding: 2300
# Item index: 2300
# Length of prefixes: 14500
# caption2embedding: 157
# Item index: 157
# Length of prefixes: 14500
# caption2embedding: 8291
# Item index: 8291
# Length of prefixes: 14500
# caption2embedding: 3240
# Item index: 3240
# coco_prefix:  96% 867/906 [09:18<00:25,  1.55it/s, loss=2.51]Length of prefixes: 14500
# caption2embedding: 11363
# Item index: 11363
# Length of prefixes: 14500
# caption2embedding: 5838
# Item index: 5838
# Length of prefixes: 14500
# caption2embedding: 4126
# Item index: 4126
# Length of prefixes: 14500
# caption2embedding: 5033
# Item index: 5033
# Length of prefixes: 14500
# caption2embedding: 14286
# Item index: 14286
# Length of prefixes: 14500
# caption2embedding: 14033
# Item index: 14033
# Length of prefixes: 14500
# caption2embedding: 9812
# Item index: 9812
# Length of prefixes: 14500
# caption2embedding: 13025
# Item index: 13025
# Length of prefixes: 14500
# caption2embedding: 7840
# Item index: 7840
# Length of prefixes: 14500
# caption2embedding: 12207
# Item index: 12207
# Length of prefixes: 14500
# caption2embedding: 5875
# Item index: 5875
# Length of prefixes: 14500
# caption2embedding: 9353
# Item index: 9353
# Length of prefixes: 14500
# caption2embedding: 6686
# Item index: 6686
# Length of prefixes: 14500
# caption2embedding: 1197
# Item index: 1197
# Length of prefixes: 14500
# caption2embedding: 10103
# Item index: 10103
# Length of prefixes: 14500
# caption2embedding: 8910
# Item index: 8910
# coco_prefix:  96% 868/906 [09:19<00:24,  1.55it/s, loss=2.56]Length of prefixes: 14500
# caption2embedding: 11429
# Item index: 11429
# Length of prefixes: 14500
# caption2embedding: 11736
# Item index: 11736
# Length of prefixes: 14500
# caption2embedding: 9079
# Item index: 9079
# Length of prefixes: 14500
# caption2embedding: 5555
# Item index: 5555
# Length of prefixes: 14500
# caption2embedding: 4320
# Item index: 4320
# Length of prefixes: 14500
# caption2embedding: 9462
# Item index: 9462
# Length of prefixes: 14500
# caption2embedding: 10605
# Item index: 10605
# Length of prefixes: 14500
# caption2embedding: 9702
# Item index: 9702
# Length of prefixes: 14500
# caption2embedding: 10152
# Item index: 10152
# Length of prefixes: 14500
# caption2embedding: 4484
# Item index: 4484
# Length of prefixes: 14500
# caption2embedding: 2326
# Item index: 2326
# Length of prefixes: 14500
# caption2embedding: 11316
# Item index: 11316
# Length of prefixes: 14500
# caption2embedding: 3799
# Item index: 3799
# Length of prefixes: 14500
# caption2embedding: 1829
# Item index: 1829
# Length of prefixes: 14500
# caption2embedding: 9658
# Item index: 9658
# Length of prefixes: 14500
# caption2embedding: 3042
# Item index: 3042
# coco_prefix:  96% 869/906 [09:20<00:23,  1.55it/s, loss=2.66]Length of prefixes: 14500
# caption2embedding: 9520
# Item index: 9520
# Length of prefixes: 14500
# caption2embedding: 8050
# Item index: 8050
# Length of prefixes: 14500
# caption2embedding: 2683
# Item index: 2683
# Length of prefixes: 14500
# caption2embedding: 14355
# Item index: 14355
# Length of prefixes: 14500
# caption2embedding: 10694
# Item index: 10694
# Length of prefixes: 14500
# caption2embedding: 6123
# Item index: 6123
# Length of prefixes: 14500
# caption2embedding: 13232
# Item index: 13232
# Length of prefixes: 14500
# caption2embedding: 4570
# Item index: 4570
# Length of prefixes: 14500
# caption2embedding: 2306
# Item index: 2306
# Length of prefixes: 14500
# caption2embedding: 2045
# Item index: 2045
# Length of prefixes: 14500
# caption2embedding: 5806
# Item index: 5806
# Length of prefixes: 14500
# caption2embedding: 11644
# Item index: 11644
# Length of prefixes: 14500
# caption2embedding: 11805
# Item index: 11805
# Length of prefixes: 14500
# caption2embedding: 6080
# Item index: 6080
# Length of prefixes: 14500
# caption2embedding: 11705
# Item index: 11705
# Length of prefixes: 14500
# caption2embedding: 11887
# Item index: 11887
# coco_prefix:  96% 870/906 [09:20<00:23,  1.55it/s, loss=2.63]Length of prefixes: 14500
# caption2embedding: 893
# Item index: 893
# Length of prefixes: 14500
# caption2embedding: 9767
# Item index: 9767
# Length of prefixes: 14500
# caption2embedding: 2569
# Item index: 2569
# Length of prefixes: 14500
# caption2embedding: 8104
# Item index: 8104
# Length of prefixes: 14500
# caption2embedding: 4947
# Item index: 4947
# Length of prefixes: 14500
# caption2embedding: 13358
# Item index: 13358
# Length of prefixes: 14500
# caption2embedding: 2850
# Item index: 2850
# Length of prefixes: 14500
# caption2embedding: 9451
# Item index: 9451
# Length of prefixes: 14500
# caption2embedding: 10062
# Item index: 10062
# Length of prefixes: 14500
# caption2embedding: 7123
# Item index: 7123
# Length of prefixes: 14500
# caption2embedding: 5617
# Item index: 5617
# Length of prefixes: 14500
# caption2embedding: 6122
# Item index: 6122
# Length of prefixes: 14500
# caption2embedding: 10958
# Item index: 10958
# Length of prefixes: 14500
# caption2embedding: 2753
# Item index: 2753
# Length of prefixes: 14500
# caption2embedding: 7087
# Item index: 7087
# Length of prefixes: 14500
# caption2embedding: 12584
# Item index: 12584
# coco_prefix:  96% 871/906 [09:21<00:22,  1.55it/s, loss=2.78]Length of prefixes: 14500
# caption2embedding: 14415
# Item index: 14415
# Length of prefixes: 14500
# caption2embedding: 3980
# Item index: 3980
# Length of prefixes: 14500
# caption2embedding: 1982
# Item index: 1982
# Length of prefixes: 14500
# caption2embedding: 12202
# Item index: 12202
# Length of prefixes: 14500
# caption2embedding: 1614
# Item index: 1614
# Length of prefixes: 14500
# caption2embedding: 3851
# Item index: 3851
# Length of prefixes: 14500
# caption2embedding: 6001
# Item index: 6001
# Length of prefixes: 14500
# caption2embedding: 3244
# Item index: 3244
# Length of prefixes: 14500
# caption2embedding: 10213
# Item index: 10213
# Length of prefixes: 14500
# caption2embedding: 7950
# Item index: 7950
# Length of prefixes: 14500
# caption2embedding: 2536
# Item index: 2536
# Length of prefixes: 14500
# caption2embedding: 716
# Item index: 716
# Length of prefixes: 14500
# caption2embedding: 9898
# Item index: 9898
# Length of prefixes: 14500
# caption2embedding: 11538
# Item index: 11538
# Length of prefixes: 14500
# caption2embedding: 5923
# Item index: 5923
# Length of prefixes: 14500
# caption2embedding: 13866
# Item index: 13866
# coco_prefix:  96% 872/906 [09:22<00:21,  1.56it/s, loss=2.61]Length of prefixes: 14500
# caption2embedding: 7526
# Item index: 7526
# Length of prefixes: 14500
# caption2embedding: 3086
# Item index: 3086
# Length of prefixes: 14500
# caption2embedding: 3450
# Item index: 3450
# Length of prefixes: 14500
# caption2embedding: 240
# Item index: 240
# Length of prefixes: 14500
# caption2embedding: 8810
# Item index: 8810
# Length of prefixes: 14500
# caption2embedding: 3137
# Item index: 3137
# Length of prefixes: 14500
# caption2embedding: 5455
# Item index: 5455
# Length of prefixes: 14500
# caption2embedding: 11141
# Item index: 11141
# Length of prefixes: 14500
# caption2embedding: 11707
# Item index: 11707
# Length of prefixes: 14500
# caption2embedding: 2068
# Item index: 2068
# Length of prefixes: 14500
# caption2embedding: 13059
# Item index: 13059
# Length of prefixes: 14500
# caption2embedding: 11079
# Item index: 11079
# Length of prefixes: 14500
# caption2embedding: 5762
# Item index: 5762
# Length of prefixes: 14500
# caption2embedding: 8928
# Item index: 8928
# Length of prefixes: 14500
# caption2embedding: 14011
# Item index: 14011
# Length of prefixes: 14500
# caption2embedding: 8249
# Item index: 8249
# coco_prefix:  96% 873/906 [09:22<00:21,  1.56it/s, loss=2.57]Length of prefixes: 14500
# caption2embedding: 6969
# Item index: 6969
# Length of prefixes: 14500
# caption2embedding: 9098
# Item index: 9098
# Length of prefixes: 14500
# caption2embedding: 1927
# Item index: 1927
# Length of prefixes: 14500
# caption2embedding: 9078
# Item index: 9078
# Length of prefixes: 14500
# caption2embedding: 9269
# Item index: 9269
# Length of prefixes: 14500
# caption2embedding: 13665
# Item index: 13665
# Length of prefixes: 14500
# caption2embedding: 126
# Item index: 126
# Length of prefixes: 14500
# caption2embedding: 4904
# Item index: 4904
# Length of prefixes: 14500
# caption2embedding: 6658
# Item index: 6658
# Length of prefixes: 14500
# caption2embedding: 2404
# Item index: 2404
# Length of prefixes: 14500
# caption2embedding: 11925
# Item index: 11925
# Length of prefixes: 14500
# caption2embedding: 8656
# Item index: 8656
# Length of prefixes: 14500
# caption2embedding: 9172
# Item index: 9172
# Length of prefixes: 14500
# caption2embedding: 6911
# Item index: 6911
# Length of prefixes: 14500
# caption2embedding: 5372
# Item index: 5372
# Length of prefixes: 14500
# caption2embedding: 11069
# Item index: 11069
# coco_prefix:  96% 874/906 [09:23<00:20,  1.55it/s, loss=2.2]Length of prefixes: 14500
# caption2embedding: 10909
# Item index: 10909
# Length of prefixes: 14500
# caption2embedding: 13888
# Item index: 13888
# Length of prefixes: 14500
# caption2embedding: 9365
# Item index: 9365
# Length of prefixes: 14500
# caption2embedding: 5798
# Item index: 5798
# Length of prefixes: 14500
# caption2embedding: 4412
# Item index: 4412
# Length of prefixes: 14500
# caption2embedding: 3398
# Item index: 3398
# Length of prefixes: 14500
# caption2embedding: 970
# Item index: 970
# Length of prefixes: 14500
# caption2embedding: 11609
# Item index: 11609
# Length of prefixes: 14500
# caption2embedding: 9706
# Item index: 9706
# Length of prefixes: 14500
# caption2embedding: 11933
# Item index: 11933
# Length of prefixes: 14500
# caption2embedding: 8062
# Item index: 8062
# Length of prefixes: 14500
# caption2embedding: 11425
# Item index: 11425
# Length of prefixes: 14500
# caption2embedding: 14082
# Item index: 14082
# Length of prefixes: 14500
# caption2embedding: 6188
# Item index: 6188
# Length of prefixes: 14500
# caption2embedding: 10282
# Item index: 10282
# Length of prefixes: 14500
# caption2embedding: 7771
# Item index: 7771
# coco_prefix:  97% 875/906 [09:24<00:19,  1.55it/s, loss=2.54]Length of prefixes: 14500
# caption2embedding: 3497
# Item index: 3497
# Length of prefixes: 14500
# caption2embedding: 3806
# Item index: 3806
# Length of prefixes: 14500
# ...
# Length of prefixes: 505
# caption2embedding: 419
# Item index: 419
# Length of prefixes: 505
# caption2embedding: 64
# Item index: 64
# Length of prefixes: 505
# caption2embedding: 139
# Item index: 139
# Length of prefixes: 505
# caption2embedding: 393
# Item index: 393
# Length of prefixes: 505
# caption2embedding: 150
# Item index: 150
# Length of prefixes: 505
# caption2embedding: 469
# Item index: 469
# Length of prefixes: 505
# caption2embedding: 29
# Item index: 29
# Length of prefixes: 505
# caption2embedding: 81
# Item index: 81
# Length of prefixes: 505
# caption2embedding: 485
# Item index: 485
# Length of prefixes: 505
# caption2embedding: 28
# Item index: 28
# Length of prefixes: 505
# caption2embedding: 486
# Item index: 486
# Length of prefixes: 505
# caption2embedding: 170
# Item index: 170
# Length of prefixes: 505
# caption2embedding: 166
# Item index: 166
# Length of prefixes: 505
# caption2embedding: 243
# Item index: 243
# Length of prefixes: 505
# caption2embedding: 275
# Item index: 275
# Length of prefixes: 505
# caption2embedding: 443
# Item index: 443
# Length of prefixes: 505
# caption2embedding: 257
# Item index: 257
# Length of prefixes: 505
# caption2embedding: 499
# Item index: 499
# Length of prefixes: 505
# caption2embedding: 326
# Item index: 326
# Length of prefixes: 505
# caption2embedding: 238
# Item index: 238
# Length of prefixes: 505
# caption2embedding: 158
# Item index: 158
# Length of prefixes: 505
# caption2embedding: 86
# Item index: 86
# Length of prefixes: 505
# caption2embedding: 476
# Item index: 476
# Length of prefixes: 505
# caption2embedding: 41
# Item index: 41
# Length of prefixes: 505
# caption2embedding: 341
# Item index: 341
# Length of prefixes: 505
# caption2embedding: 181
# Item index: 181
# Length of prefixes: 505
# caption2embedding: 232
# Item index: 232
# Length of prefixes: 505
# caption2embedding: 227
# Item index: 227
# Length of prefixes: 505
# caption2embedding: 504
# Item index: 504
# Length of prefixes: 505
# caption2embedding: 195
# Item index: 195
# Length of prefixes: 505
# caption2embedding: 406
# Item index: 406
# Length of prefixes: 505
# caption2embedding: 395
# Item index: 395
# Length of prefixes: 505
# caption2embedding: 126
# Item index: 126
# Length of prefixes: 505
# caption2embedding: 115
# Item index: 115
# Length of prefixes: 505
# caption2embedding: 85
# Item index: 85
# Length of prefixes: 505
# caption2embedding: 398
# Item index: 398
# Length of prefixes: 505
# caption2embedding: 225
# Item index: 225
# Length of prefixes: 505
# caption2embedding: 498
# Item index: 498
# Length of prefixes: 505
# caption2embedding: 174
# Item index: 174
# Length of prefixes: 505
# caption2embedding: 76
# Item index: 76
# Length of prefixes: 505
# caption2embedding: 360
# Item index: 360
# Length of prefixes: 505
# caption2embedding: 156
# Item index: 156
# Length of prefixes: 505
# caption2embedding: 383
# Item index: 383
# Length of prefixes: 505
# caption2embedding: 17
# Item index: 17
# Length of prefixes: 505
# caption2embedding: 295
# Item index: 295
# Length of prefixes: 505
# caption2embedding: 497
# Item index: 497
# Length of prefixes: 505
# caption2embedding: 209
# Item index: 209
# Length of prefixes: 505
# caption2embedding: 503
# Item index: 503
# Length of prefixes: 505
# caption2embedding: 93
# Item index: 93
# Length of prefixes: 505
# caption2embedding: 106
# Item index: 106
# Length of prefixes: 505
# caption2embedding: 332
# Item index: 332
# Length of prefixes: 505
# caption2embedding: 58
# Item index: 58
# Length of prefixes: 505
# caption2embedding: 7
# Item index: 7
# Length of prefixes: 505
# caption2embedding: 324
# Item index: 324
# Length of prefixes: 505
# caption2embedding: 239
# Item index: 239
# Length of prefixes: 505
# caption2embedding: 472
# Item index: 472
# Length of prefixes: 505
# caption2embedding: 416
# Item index: 416
# Length of prefixes: 505
# caption2embedding: 342
# Item index: 342
# Length of prefixes: 505
# caption2embedding: 98
# Item index: 98
# Length of prefixes: 505
# caption2embedding: 367
# Item index: 367
# Length of prefixes: 505
# caption2embedding: 194
# Item index: 194
# Length of prefixes: 505
# caption2embedding: 308
# Item index: 308
# Length of prefixes: 505
# caption2embedding: 206
# Item index: 206
# Length of prefixes: 505
# caption2embedding: 132
# Item index: 132
# Length of prefixes: 505
# caption2embedding: 263
# Item index: 263
# Length of prefixes: 505
# caption2embedding: 440
# Item index: 440
# Length of prefixes: 505
# caption2embedding: 177
# Item index: 177
# Length of prefixes: 505
# caption2embedding: 446
# Item index: 446
# Length of prefixes: 505
# caption2embedding: 379
# Item index: 379
# Length of prefixes: 505
# caption2embedding: 103
# Item index: 103
# Length of prefixes: 505
# caption2embedding: 285
# Item index: 285
# Length of prefixes: 505
# caption2embedding: 92
# Item index: 92
# Length of prefixes: 505
# caption2embedding: 431
# Item index: 431
# Length of prefixes: 505
# caption2embedding: 16
# Item index: 16
# Length of prefixes: 505
# caption2embedding: 426
# Item index: 426
# Length of prefixes: 505
# caption2embedding: 66
# Item index: 66
# Length of prefixes: 505
# caption2embedding: 340
# Item index: 340
# Length of prefixes: 505
# caption2embedding: 351
# Item index: 351
# Length of prefixes: 505
# caption2embedding: 10
# Item index: 10
# Length of prefixes: 505
# caption2embedding: 55
# Item index: 55
# Length of prefixes: 505
# caption2embedding: 414
# Item index: 414
# Length of prefixes: 505
# caption2embedding: 264
# Item index: 264
# Length of prefixes: 505
# caption2embedding: 65
# Item index: 65
# Length of prefixes: 505
# caption2embedding: 317
# Item index: 317
# Length of prefixes: 505
# caption2embedding: 197
# Item index: 197
# Length of prefixes: 505
# caption2embedding: 441
# Item index: 441
# Length of prefixes: 505
# caption2embedding: 478
# Item index: 478
# Length of prefixes: 505
# caption2embedding: 105
# Item index: 105
# Length of prefixes: 505
# caption2embedding: 94
# Item index: 94
# Length of prefixes: 505
# caption2embedding: 354
# Item index: 354
# Length of prefixes: 505
# caption2embedding: 492
# Item index: 492
# Length of prefixes: 505
# caption2embedding: 214
# Item index: 214
# Length of prefixes: 505
# caption2embedding: 153
# Item index: 153
# Length of prefixes: 505
# caption2embedding: 198
# Item index: 198
# Length of prefixes: 505
# caption2embedding: 377
# Item index: 377
# Length of prefixes: 505
# caption2embedding: 333
# Item index: 333
# Length of prefixes: 505
# caption2embedding: 75
# Item index: 75
# Length of prefixes: 505
# caption2embedding: 186
# Item index: 186
# Length of prefixes: 505
# caption2embedding: 149
# Item index: 149
# Length of prefixes: 505
# caption2embedding: 356
# Item index: 356
# Length of prefixes: 505
# caption2embedding: 260
# Item index: 260
# Length of prefixes: 505
# caption2embedding: 108
# Item index: 108
# Length of prefixes: 505
# caption2embedding: 39
# Item index: 39
# Length of prefixes: 505
# caption2embedding: 191
# Item index: 191
# Length of prefixes: 505
# caption2embedding: 59
# Item index: 59
# Length of prefixes: 505
# caption2embedding: 157
# Item index: 157
# Length of prefixes: 505
# caption2embedding: 321
# Item index: 321
# Length of prefixes: 505
# caption2embedding: 266
# Item index: 266
# Length of prefixes: 505
# caption2embedding: 361
# Item index: 361
# Length of prefixes: 505
# caption2embedding: 415
# Item index: 415
# Length of prefixes: 505
# caption2embedding: 413
# Item index: 413
# Length of prefixes: 505
# caption2embedding: 97
# Item index: 97
# Length of prefixes: 505
# caption2embedding: 286
# Item index: 286
# Length of prefixes: 505
# caption2embedding: 451
# Item index: 451
# Length of prefixes: 505
# caption2embedding: 316
# Item index: 316
# Length of prefixes: 505
# caption2embedding: 300
# Item index: 300
# Length of prefixes: 505
# caption2embedding: 3
# Item index: 3
# Length of prefixes: 505
# caption2embedding: 36
# Item index: 36
# Length of prefixes: 505
# caption2embedding: 233
# Item index: 233
# Length of prefixes: 505
# caption2embedding: 241
# Item index: 241
# Length of prefixes: 505
# caption2embedding: 140
# Item index: 140
# Length of prefixes: 505
# caption2embedding: 322
# Item index: 322
# Length of prefixes: 505
# caption2embedding: 461
# Item index: 461
# Length of prefixes: 505
# caption2embedding: 337
# Item index: 337
# Length of prefixes: 505
# caption2embedding: 298
# Item index: 298
# Length of prefixes: 505
# caption2embedding: 408
# Item index: 408
# Length of prefixes: 505
# caption2embedding: 365
# Item index: 365
# Length of prefixes: 505
# caption2embedding: 35
# Item index: 35
# Length of prefixes: 505
# caption2embedding: 331
# Item index: 331
# Length of prefixes: 505
# caption2embedding: 218
# Item index: 218
# Length of prefixes: 505
# caption2embedding: 346
# Item index: 346
# Length of prefixes: 505
# caption2embedding: 168
# Item index: 168
# Length of prefixes: 505
# caption2embedding: 129
# Item index: 129
# Length of prefixes: 505
# caption2embedding: 282
# Item index: 282
# Length of prefixes: 505
# caption2embedding: 171
# Item index: 171
# Length of prefixes: 505
# caption2embedding: 11
# Item index: 11
# Length of prefixes: 505
# caption2embedding: 119
# Item index: 119
# Length of prefixes: 505
# caption2embedding: 192
# Item index: 192
# Length of prefixes: 505
# caption2embedding: 77
# Item index: 77
# Length of prefixes: 505
# caption2embedding: 216
# Item index: 216
# Length of prefixes: 505
# caption2embedding: 215
# Item index: 215
# Length of prefixes: 505
# caption2embedding: 48
# Item index: 48
# Length of prefixes: 505
# caption2embedding: 114
# Item index: 114
# Length of prefixes: 505
# caption2embedding: 113
# Item index: 113
# Length of prefixes: 505
# caption2embedding: 277
# Item index: 277
# Length of prefixes: 505
# caption2embedding: 394
# Item index: 394
# Length of prefixes: 505
# caption2embedding: 423
# Item index: 423
# Length of prefixes: 505
# caption2embedding: 403
# Item index: 403
# Length of prefixes: 505
# caption2embedding: 343
# Item index: 343
# Length of prefixes: 505
# caption2embedding: 313
# Item index: 313
# Length of prefixes: 505
# caption2embedding: 179
# Item index: 179
# Length of prefixes: 505
# caption2embedding: 409
# Item index: 409
# Length of prefixes: 505
# caption2embedding: 296
# Item index: 296
# Length of prefixes: 505
# caption2embedding: 412
# Item index: 412
# Length of prefixes: 505
# caption2embedding: 163
# Item index: 163
# Length of prefixes: 505
# caption2embedding: 180
# Item index: 180
# Length of prefixes: 505
# caption2embedding: 165
# Item index: 165
# Length of prefixes: 505
# caption2embedding: 6
# Item index: 6
# Length of prefixes: 505
# caption2embedding: 352
# Item index: 352
# Length of prefixes: 505
# caption2embedding: 47
# Item index: 47
# Length of prefixes: 505
# caption2embedding: 457
# Item index: 457
# Length of prefixes: 505
# caption2embedding: 265
# Item index: 265
# Length of prefixes: 505
# caption2embedding: 19
# Item index: 19
# Length of prefixes: 505
# caption2embedding: 60
# Item index: 60
# Length of prefixes: 505
# caption2embedding: 287
# Item index: 287
# Length of prefixes: 505
# caption2embedding: 154
# Item index: 154
# Length of prefixes: 505
# caption2embedding: 230
# Item index: 230
# Length of prefixes: 505
# caption2embedding: 144
# Item index: 144
# Length of prefixes: 505
# caption2embedding: 162
# Item index: 162
# Length of prefixes: 505
# caption2embedding: 169
# Item index: 169
# Length of prefixes: 505
# caption2embedding: 345
# Item index: 345
# Length of prefixes: 505
# caption2embedding: 359
# Item index: 359
# Length of prefixes: 505
# caption2embedding: 87
# Item index: 87
# Length of prefixes: 505
# caption2embedding: 147
# Item index: 147
# Length of prefixes: 505
# caption2embedding: 427
# Item index: 427
# Length of prefixes: 505
# caption2embedding: 493
# Item index: 493
# Length of prefixes: 505
# caption2embedding: 220
# Item index: 220
# Length of prefixes: 505
# caption2embedding: 482
# Item index: 482
# Length of prefixes: 505
# caption2embedding: 276
# Item index: 276
# Length of prefixes: 505
# caption2embedding: 229
# Item index: 229
# Length of prefixes: 505
# caption2embedding: 24
# Item index: 24
# Length of prefixes: 505
# caption2embedding: 30
# Item index: 30
# Length of prefixes: 505
# caption2embedding: 247
# Item index: 247
# Length of prefixes: 505
# caption2embedding: 304
# Item index: 304
# Length of prefixes: 505
# caption2embedding: 184
# Item index: 184
# Length of prefixes: 505
# caption2embedding: 330
# Item index: 330
# Length of prefixes: 505
# caption2embedding: 34
# Item index: 34
# Length of prefixes: 505
# caption2embedding: 334
# Item index: 334
# Length of prefixes: 505
# caption2embedding: 201
# Item index: 201
# Length of prefixes: 505
# caption2embedding: 444
# Item index: 444
# Length of prefixes: 505
# caption2embedding: 234
# Item index: 234
# Length of prefixes: 505
# caption2embedding: 279
# Item index: 279
# Length of prefixes: 505
# caption2embedding: 240
# Item index: 240
# Length of prefixes: 505
# caption2embedding: 433
# Item index: 433
# Length of prefixes: 505
# caption2embedding: 391
# Item index: 391
# Length of prefixes: 505
# caption2embedding: 309
# Item index: 309
# Length of prefixes: 505
# caption2embedding: 223
# Item index: 223
# Length of prefixes: 505
# caption2embedding: 474
# Item index: 474
# Length of prefixes: 505
# caption2embedding: 152
# Item index: 152
# Length of prefixes: 505
# caption2embedding: 134
# Item index: 134
# Length of prefixes: 505
# caption2embedding: 370
# Item index: 370
# Length of prefixes: 505
# caption2embedding: 161
# Item index: 161
# Length of prefixes: 505
# caption2embedding: 466
# Item index: 466
# Length of prefixes: 505
# caption2embedding: 32
# Item index: 32
# Length of prefixes: 505
# caption2embedding: 373
# Item index: 373
# Length of prefixes: 505
# caption2embedding: 329
# Item index: 329
# Length of prefixes: 505
# caption2embedding: 462
# Item index: 462
# Length of prefixes: 505
# caption2embedding: 339
# Item index: 339
# Length of prefixes: 505
# caption2embedding: 358
# Item index: 358
# Length of prefixes: 505
# caption2embedding: 319
# Item index: 319
# Length of prefixes: 505
# caption2embedding: 187
# Item index: 187
# Length of prefixes: 505
# caption2embedding: 83
# Item index: 83
# Length of prefixes: 505
# caption2embedding: 490
# Item index: 490
# Length of prefixes: 505
# caption2embedding: 421
# Item index: 421
# Length of prefixes: 505
# caption2embedding: 301
# Item index: 301
# Length of prefixes: 505
# caption2embedding: 495
# Item index: 495
# Length of prefixes: 505
# caption2embedding: 294
# Item index: 294
# Length of prefixes: 505
# caption2embedding: 95
# Item index: 95
# Length of prefixes: 505
# caption2embedding: 397
# Item index: 397
# Length of prefixes: 505
# caption2embedding: 405
# Item index: 405
# Length of prefixes: 505
# caption2embedding: 470
# Item index: 470
# Length of prefixes: 505
# caption2embedding: 386
# Item index: 386
# Length of prefixes: 505
# caption2embedding: 137
# Item index: 137
# Length of prefixes: 505
# caption2embedding: 211
# Item index: 211
# Length of prefixes: 505
# caption2embedding: 38
# Item index: 38
# Length of prefixes: 505
# caption2embedding: 1
# Item index: 1
# Length of prefixes: 505
# caption2embedding: 37
# Item index: 37
# Length of prefixes: 505
# caption2embedding: 145
# Item index: 145
# Length of prefixes: 505
# caption2embedding: 376
# Item index: 376
# Length of prefixes: 505
# caption2embedding: 488
# Item index: 488
# Length of prefixes: 505
# caption2embedding: 388
# Item index: 388
# Length of prefixes: 505
# caption2embedding: 50
# Item index: 50
# Length of prefixes: 505
# caption2embedding: 436
# Item index: 436
# Length of prefixes: 505
# caption2embedding: 120
# Item index: 120
# Length of prefixes: 505
# caption2embedding: 284
# Item index: 284
# Length of prefixes: 505
# caption2embedding: 291
# Item index: 291
# Length of prefixes: 505
# caption2embedding: 437
# Item index: 437
# Length of prefixes: 505
# caption2embedding: 288
# Item index: 288
# Length of prefixes: 505
# caption2embedding: 57
# Item index: 57
# Length of prefixes: 505
# caption2embedding: 335
# Item index: 335
# Length of prefixes: 505
# caption2embedding: 455
# Item index: 455
# Length of prefixes: 505
# caption2embedding: 18
# Item index: 18
# Length of prefixes: 505
# caption2embedding: 228
# Item index: 228
# Length of prefixes: 505
# caption2embedding: 463
# Item index: 463
# Length of prefixes: 505
# caption2embedding: 502
# Item index: 502
# Length of prefixes: 505
# caption2embedding: 212
# Item index: 212
# Length of prefixes: 505
# caption2embedding: 131
# Item index: 131
# Length of prefixes: 505
# caption2embedding: 456
# Item index: 456
# Length of prefixes: 505
# caption2embedding: 185
# Item index: 185
# Length of prefixes: 505
# caption2embedding: 249
# Item index: 249
# Length of prefixes: 505
# caption2embedding: 424
# Item index: 424
# Length of prefixes: 505
# caption2embedding: 336
# Item index: 336
# loss_per_epoch_val:  [3.1507184659281084, 3.0172107373514483, 2.933591942633352, 2.8060821256329938, 2.766251725535239, 2.726457234351866, 2.703891650322945, 2.689204954331921, 2.675554552385884, 2.681402967822167]
